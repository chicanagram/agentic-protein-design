# %% [markdown]
# # 02 - Binding Pocket Analysis
#
# Notebook UI for UPO homolog pocket analysis using an LLM with binding, alignment, and optional reaction inputs.

# %% [markdown]
# ## Python Path Setup
# Ensure project-root imports work whether Jupyter starts from repo root or `notebooks/`.

# %%
from pathlib import Path
import os
import sys

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %% [markdown]
# ## Imports
# Load helper functions for table loading, LLM analysis, output export, and thread persistence.

# %%
import importlib
import notebook_helpers.nb_02_binding_pocket_analysis as bp
bp = importlib.reload(bp)
from local_api_keys import OPENAI_API_KEY

analyze_pocket_profiles = bp.analyze_pocket_profiles
default_user_inputs = bp.default_user_inputs
build_prompt_with_context = bp.build_prompt_with_context
generate_llm_pocket_analysis = bp.generate_llm_pocket_analysis
init_thread = bp.init_thread
load_input_tables = bp.load_input_tables
persist_thread_update = bp.persist_thread_update
save_binding_outputs = bp.save_binding_outputs
save_llm_analysis = bp.save_llm_analysis
setup_data_root = bp.setup_data_root

# %% [markdown]
# ## API Key Setup
# Load the OpenAI key from `local_api_keys.py` into environment variables for LLM calls.

# %%
if OPENAI_API_KEY and OPENAI_API_KEY != "REPLACE_WITH_YOUR_OPENAI_API_KEY":
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

"OPENAI_API_KEY" in os.environ
# Out:
# True

# %% [markdown]
# ## User Inputs
# Edit all run parameters here (single place): dataset root, thread selection, analysis options, model, and input paths.

# %%
root_key = "PIPS2"
existing_thread_id = "59353c876ab140688b1c239a15aac24e"# None

user_inputs = {
    "selected_positions": None, # [100, 103, 104, 107, 141, 222],
    "pairwise_comparisons":  [("CviUPO", "ET096")], # None
    "focus_question": (
        "Identify per-protein structural interpretations and cross-homolog patterns "
        "that could explain activity/property differences."
    ),
    "reaction_data_description": (
        "- Veratryl alcohol: peroxygenative\n"
        "- Naphthalene: peroxygenative\n"
        "- NBD: peroxygenative\n"
        "- ABTS: peroxidative\n"
        "- S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased\n"
        "Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance."
    ),
    "use_reaction_data": True,
    "llm_model": "gpt-5.2",
    "llm_temperature": 0.2,
    "llm_max_rows_per_table": 300,
}

input_paths = {
    # Paths are relative to the data root from variables.address_dict[root_key].
    "binding_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv",
    "alignment_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv",
    "reaction_data_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv",
}

# Optional: reset analysis options from helper defaults
# user_inputs = default_user_inputs()

# %% [markdown]
# ## Setup Runtime Context
# Initialize data directories and active chat thread from the values above.

# %%
data_root, resolved_dirs = setup_data_root(root_key)
thread, threads_preview = init_thread(root_key, existing_thread_id)
thread_id = thread["thread_id"]
data_root, thread_id
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data'),
#  '59353c876ab140688b1c239a15aac24e')

# %% [markdown]
# ## Load Input Tables
# Load descriptor and alignment tables, and optional reaction data, from `input_paths`.

# %%
def resolve_input_path(path_value: str) -> Path:
    p = Path(path_value).expanduser()
    if p.is_absolute():
        return p.resolve()
    return (data_root / p).resolve()

binding_csv = resolve_input_path(input_paths["binding_csv"])
alignment_csv = resolve_input_path(input_paths["alignment_csv"])
reaction_data_csv = None
if user_inputs.get("use_reaction_data", False) and input_paths.get("reaction_data_csv", "").strip():
    reaction_data_csv = resolve_input_path(input_paths["reaction_data_csv"])

pocket, ali, reaction_df = load_input_tables(binding_csv, alignment_csv, reaction_data_csv)
binding_csv, alignment_csv, reaction_data_csv, pocket.head(3), (None if reaction_df is None else reaction_df.head(3))
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv'),
#     Unnamed: 0                    struct_name                  struct_name.1  \
#  0           0                ET096_S82_glide                ET096_S82_glide
#  1           1               CviUPO_S82_glide               CviUPO_S82_glide
#  2           2  CviUPO-F88L+T158A_S82_chai1_0  CviUPO-F88L+T158A_S82_chai1_0
#
#                     struct_name.2  num_pocket_res_ali  num_pocket_res<6  \
#  0                ET096_S82_glide                  38                12
#  1               CviUPO_S82_glide                  39                13
#  2  CviUPO-F88L+T158A_S82_chai1_0                  33                10
#
#     reactive_center_distance  median_dist_res_to_ligand_reactive_center  \
#  0                     7.095                                      7.921
#  1                     7.720                                      6.683
#  2                     5.827                                      6.922
#
#     median_min_dist_res_to_ligand  mean_min_dist_to_centroid (distal)  ...  \
#  0                          4.330                               8.570  ...
#  1                          3.575                               8.079  ...
#  2                          4.155                               7.691  ...
#
#     kd_weighted (distal)  kd_weighted (proximal)  hw_mean (distal)  \
#  0                 0.967                   2.177            -0.466
#  1                 0.387                   1.055            -0.546
#  2                 0.730                   1.400            -0.658
#
#     hw_mean (proximal)  hw_weighted (distal)  hw_weighted (proximal)  \
#  0              -0.864                -0.464                  -0.940
#  1              -0.946                -0.475                  -0.825
#  2              -0.900                -0.533                  -0.792
#
#     charged_fraction (distal)  charged_fraction (proximal)  \
#  0                      0.132                        0.000
#  1                      0.128                        0.077
#  2                      0.121                        0.077
#
#     polar_fraction (distal)  polar_fraction (proximal)
#  0                    0.368                      0.182
#  1                    0.513                      0.385
#  2                    0.485                      0.308
#
#  [3 rows x 41 columns],
#    UPO Homologs  Veratryl alcohol (peroxygenation)  \
#  0        ET096                              0.597
#  1       CviUPO                              0.333
#  2       DcaUPO                              1.558
#
#     Naphthalene (peroxygenation)  NBD (peroxygenation)  ABTS (peroxidation)  \
#  0                         0.127                 0.053                0.146
#  1                         0.168                 0.169                3.939
#  2                         0.136                 1.242                2.700
#
#     S82 Mono-Ox %yield  S82 Di-Ox % Yield  S82 Total % Yield  S82 Mono:Di Ratio
#  0                 8.4               32.7               41.1                0.3
#  1                14.8                8.9               23.7                1.7
#  2                10.0                6.2               16.2                1.6  )

# %% [markdown]
# ## Structured Exports
# Generate heuristic comparative tables and export CSVs to `processed/`.

# %%
selected_positions = user_inputs["selected_positions"]
interp_df, pattern_summary = analyze_pocket_profiles(pocket, ali, selected_positions)
out_interp, out_patterns = save_binding_outputs(interp_df, pattern_summary, resolved_dirs["processed"])
out_interp, out_patterns
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_interpretations.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_pattern_summary.csv'))

# %% [markdown]
# ## LLM Pocket Analysis
# Query the LLM client with the full prompt and input tables, then save markdown output.
#
# Prerequisite: set `OPENAI_API_KEY` in `local_api_keys.py`.

# %%
# Run two-stage LLM analysis (the helper prints Prompt 1/2 and Output 1/2)
llm_analysis = generate_llm_pocket_analysis(pocket, ali, reaction_df, user_inputs)
out_llm = save_llm_analysis(llm_analysis, resolved_dirs["processed"])
out_llm
# Out:
# === Prompt 1 Sent To LLM ===
#
# Analyse the uploaded inputs for a set of proteins to interpret how binding-pocket structure relates to catalytic activity and selectivity.
# Consider how both the proximal (<6 Å from docked ligand) and distal (up to ~11 Å from binding pocket centroid) residues affect the binding pocket environment.
#
# INPUTS
# - binding_pocket_table: extracted binding-pocket properties (per protein), calculated separately over proximal and distal residue sets where available.
# - pocket_alignment_table: filtered residue alignment of pocket-proximal positions.
# - reaction_data (optional): enzyme activity data on substrates.
#
# OBJECTIVE
# For each protein, integrate structural descriptors with (optional) reaction data to infer mechanistic behavior and classify pocket phenotypes.
#
# TASKS
#
# 1) For each protein:
#    - Generate a punchy tagline.
#    - Provide a concise 5-6 bullet summary addressing:
#         (i) proximal electrostatics
#         (ii) proximal sterics
#         (iii) distal electrostatics
#         (iv) distal sterics / outer pocket size
#         (v) overall synthesis of pocket phenotype, integrating structural properties with catalytic implications:
#             - Interpret how geometry and chemistry influence productive (peroxygenative) vs competing (peroxidative) pathways.
#             - If reaction_data is provided, use it to support structure–function relationships.
#
#    Use the following column groups:
#
#    PROXIMAL ELECTROSTATICS
#    - charged_fraction (proximal), polar_fraction (proximal)
#    - kd_weighted (proximal), hw_weighted (proximal)
#    - median_dist_res_to_ligand_reactive_center
#
#    PROXIMAL STERICS
#    - mean_volume (proximal), weighted_mean_volume (proximal)
#    - volume_variance (proximal)
#    - small_residue_frac (proximal), bulky_residue_frac (proximal)
#    - median_min_dist_res_to_ligand
#    - reactive_center_distance
#    - num_pocket_res_lt6
#
#    DISTAL ELECTROSTATICS
#    - charged_fraction (distal), polar_fraction (distal)
#    - kd_weighted (distal), hw_weighted (distal)
#
#    DISTAL STERICS / OUTER POCKET SIZE
#    - mean_dist_to_centroid
#    - mean_min_dist_to_centroid
#    - mean_dist_backbone_to_centroid
#    - mean_volume (distal)
#    - volume_variance (distal)
#    - small_residue_frac (distal), bulky_residue_frac (distal)
#    - num_pocket_res_ali
#
#    If proximal/distal suffixes are not explicitly present, infer proximal/distal groupings from context and state your assumption briefly.
#
# 2) Comparative analysis requirements (do BOTH):
#    A) Intra-protein variant analysis (MANDATORY when variants are present):
#    - Detect proteins that share the same base protein identity but differ by variant/mutation labels.
#    - For each such protein family, explicitly compare each variant against its WT/reference form (if WT/reference is present).
#    - If WT is not explicitly labeled, infer the closest reference sequence in that family and state the assumption.
#    - For each variant-vs-reference comparison, report which structural dimensions changed:
#         (i) proximal electrostatics
#         (ii) proximal sterics
#         (iii) distal electrostatics
#         (iv) distal sterics / outer pocket size
#    - Provide a mechanistic rationale linking those differences to functional shifts.
#
#    B) User-requested pairwise comparisons:
#    - Pairwise comparisons requested: CviUPO vs ET096
#    - Perform each requested pairwise comparison in addition to section A.
#    - Explicitly contrast which structural dimensions changed (prox electrostatics, prox sterics, distal electrostatics, distal sterics).
#    - Provide a mechanistic rationale for functional shifts.
#
# 3) Distill cross-protein trends or clusters (“pocket phenotypes”):
#    - Identify recurring structural archetypes (e.g., tight/polar pose-locking vs open/hydrophobic permissive).
#    - Link clusters to turnover vs selectivity trade-offs.
#
# OUTPUT STYLE
# - Clear, human-interpretable, mechanistically grounded.
# - Emphasize intuition over raw numbers.
# - Keep summaries compact and comparative.
#
#
# REACTION CONTEXT (OPTIONAL)
# - Veratryl alcohol: peroxygenative
# - Naphthalene: peroxygenative
# - NBD: peroxygenative
# - ABTS: peroxidative
# - S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased
# Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance.
#
# REACTION_DATA_STATUS: provided. Rows=5, Columns=['UPO Homologs', 'Veratryl alcohol (peroxygenation)', 'Naphthalene (peroxygenation)', 'NBD (peroxygenation)', 'ABTS (peroxidation)', 'S82 Mono-Ox %yield', 'S82 Di-Ox % Yield', 'S82 Total % Yield', 'S82 Mono:Di Ratio']
#
# === LLM Output 1 ===
# ## Per-protein interpretations (proximal <6 Å; distal ~6–11 Å)
#
# ### ET096 — **“Wide, dry active site: fast turnover, sloppy control.”**
# - **Prox electrostatics:** Very low **charged_fraction (0.0)** and low **polar_fraction (0.182)** → weak H-bond/ionic “pose-locking”; high **kd_weighted (2.177)** with strongly negative **hw_weighted (-0.94)** suggests a **hydrophobic, dispersion-driven** near field. Reactive-center proximity is relatively **far** (**reactive_center_distance 7.10 Å**; **median_dist_res_to_ligand_reactive_center 7.92 Å**) → less precise oxidant–substrate geometry.
# - **Prox sterics:** Many close residues (**num_pocket_res<6 = 12**) but they are **small-biased** (**small_residue_frac 0.636**) with lower mean volume (**88 Å³**) → “roomy” microcavity despite contacts; **median_min_dist_res_to_ligand 4.33 Å** indicates fewer tight clamps.
# - **Distal electrostatics:** Some charge/polarity appears distally (**charged_fraction 0.132; polar_fraction 0.368**) but **kd_weighted 0.967** is modest → distal shell not strongly polar/charged enough to enforce a single productive binding mode.
# - **Distal sterics / outer size:** Distal centroid distances are the **largest** in the set (**mean_dist_to_centroid 10.25 Å**) → expanded outer pocket/vestibule that can admit multiple poses.
# - **Phenotype & catalytic implication:** **Open/hydrophobic permissive** pocket tends to allow **multiple substrate orientations**, increasing chances of **unproductive/peroxidative** electron-transfer events. This matches reaction data: **high total S82 yield (41.1%) but strongly Di-Ox biased** (**Mono:Di 0.3**)—consistent with less geometric control and easier secondary oxidation. Despite that, ET096 shows decent peroxygenation on veratryl alcohol (0.597), likely from high accessibility rather than tight positioning.
#
# ---
#
# ### CviUPO — **“Polar-and-bulky pose clamp: selective mono-oxidizer, peroxidase-prone.”**
# - **Prox electrostatics:** Higher **polar_fraction (0.385)** and some **charge (0.077)** → stronger local H-bonding/electrostatic steering; lower **kd_weighted (1.055)** than ET096 suggests less purely hydrophobic packing. Reactive-center distances are **somewhat closer** (**median_dist_res_to_ligand_reactive_center 6.68 Å**) but **reactive_center_distance 7.72 Å** indicates the docked reactive atom is still not extremely “pressed” into the oxidant zone.
# - **Prox sterics:** **Very bulky proximal shell** (**bulky_residue_frac 0.615**, mean_volume **111 Å³**) and **tight ligand approach** (**median_min_dist_res_to_ligand 3.58 Å**) → strong steric gating that can enforce a preferred pose.
# - **Distal electrostatics:** Distal region is the **most polar** here (**polar_fraction 0.513**) with modest charge (**0.128**) → can stabilize polar transition-state-like orientations and/or facilitate electron-transfer networks.
# - **Distal sterics / outer size:** Outer pocket is not huge (**mean_dist_to_centroid 9.91 Å**) but is well “lined” (**num_pocket_res_ali 39**) → structured second shell.
# - **Phenotype & catalytic implication:** **Pose-locking, polar-lined** pocket supports **mono-oxidation selectivity** (S82 **Mono:Di 1.7**). However, the same polarity/charge (prox + distal) can also support **peroxidative pathways** (easier outer-sphere ET / radical propagation), consistent with **very high ABTS activity (3.939)** relative to ET096.
#
# ---
#
# ### CviUPO-F88L+T158A — **“Loosened Cvi clamp: closer reactive approach but less electrostatic guidance.”**
# *(No reaction data row provided for this variant; inference is structural.)*
# - **Prox electrostatics:** Similar **charged_fraction (0.077)** but **lower polar_fraction (0.308 vs 0.385 in CviUPO)**; **kd_weighted increases (1.4 vs 1.055)** → proximal environment becomes **less polar/more hydrophobic**, reducing pose-specific H-bonding.
# - **Prox sterics:** Still bulky (**bulky_residue_frac 0.615**) but **reactive_center_distance drops strongly (5.83 Å vs 7.72 Å)** → the docked reactive atom is positioned **closer to the catalytic center**, which can increase peroxygenative competence *if* orientation is correct. Fewer close residues (**num_pocket_res<6 = 10**) suggests slightly reduced “clamp density.”
# - **Distal electrostatics:** Distal becomes **less polar** than CviUPO (**polar_fraction 0.485 vs 0.513**) and **kd_weighted rises (0.73 vs 0.387)** → weaker distal electrostatic shaping.
# - **Distal sterics / outer size:** Slightly more compact outer shell (**mean_dist_to_centroid 9.63 Å**) with fewer aligned residues (**num_pocket_res_ali 33**) → potentially more flexible/less constrained pocket architecture.
# - **Phenotype & catalytic implication:** Likely shifts from **high-selectivity pose-locking** toward **more permissive hydrophobic binding**, while simultaneously allowing **closer reactive approach**. Net expectation: potentially **higher turnover** on some substrates but **reduced mono-selectivity** (more Di-Ox risk) unless the closer approach is accompanied by correct orientation constraints.
#
# ---
#
# ### DcaUPO — **“Reactive-center striker: high peroxygenation with a charged outer shell.”**
# - **Prox electrostatics:** Low proximal polarity (**polar_fraction 0.154**) with some charge (**0.077**); high **kd_weighted (1.785)** and very negative **hw_weighted (-1.042)** → proximal region is **hydrophobic**, not H-bond rich.
# - **Prox sterics:** Bulky proximal lining (**bulky_residue_frac 0.615**) plus **largest number of close residues** (**num_pocket_res<6 = 15**) → strong steric shaping. Critically, **reactive_center_distance is small (4.93 Å)** → geometry favors productive oxygen transfer.
# - **Distal electrostatics:** Distal shell has the **highest charge fraction (0.20)** with moderate polarity (**0.40**) → can support proton/electron management and may also enable peroxidative ET depending on substrate.
# - **Distal sterics / outer size:** Outer pocket size is midrange (**mean_dist_to_centroid 10.00 Å**), with high proximal volume variance (**1183**) → suggests heterogeneous microenvironments/alternate microposes near the ligand.
# - **Phenotype & catalytic implication:** Combination of **close reactive approach** + **steric shaping** explains strong peroxygenation on challenging substrates (**veratryl alcohol 1.558; NBD 1.242**). Yet substantial distal charge aligns with **high ABTS (2.7)**—DcaUPO appears **bifunctional**, capable of both peroxygenative and peroxidative chemistry depending on substrate access/orientation. S82 shows **mono-biased** (**Mono:Di 1.6**) but lower total yield (16.2%), consistent with a more “demanding” geometry that is productive when satisfied.
#
# ---
#
# ### TE314 — **“Balanced pocket: moderate control, moderate over-oxidation.”**
# - **Prox electrostatics:** No proximal charge (**0.0**) but moderate polarity (**0.308**); **kd_weighted 1.821** indicates hydrophobic packing still dominates. Reactive-center placement is **closest in the set** (**reactive_center_distance 4.08 Å**) but **median_dist_res_to_ligand_reactive_center is high (8.21 Å)**, implying the *reactive atom* is close while many residues are not tightly arranged around it (less “caging”).
# - **Prox sterics:** Proximal residues are not especially bulky (**bulky_residue_frac 0.308**) and mean volume is lower (**98.5 Å³**) → less steric gating than Cvi/Dca. **median_min_dist_res_to_ligand 4.49 Å** suggests looser packing.
# - **Distal electrostatics:** Distal is relatively hydrophobic (**kd_weighted 1.428**) with modest polarity (**0.371**) → weaker long-range steering.
# - **Distal sterics / outer size:** Outer pocket is relatively compact (**mean_dist_to_centroid 9.73 Å**) with moderate residue count (**35**).
# - **Phenotype & catalytic implication:** **Good reactive access** but **weaker pose-locking** → tends toward **higher total oxidation** with more over-oxidation risk. Reaction data supports this: decent total S82 (36.5%) but **Di-Ox favored** (**Mono:Di 0.7**).
#
# ---
#
# ### OA167 — **“Hydrophobic squeeze with a roomy vestibule: high throughput, Di-Ox drift.”**
# - **Prox electrostatics:** No proximal charge (**0.0**) with moderate polarity (**0.308**); strongly hydrophobic signature (**hw_weighted -1.359**, most negative) and moderate **kd_weighted 1.405** → near-field is **very nonpolar**.
# - **Prox sterics:** Bulky proximal lining (**bulky_residue_frac 0.538**) with **large weighted_mean_volume (111 Å³)** and **tight ligand approach** (**median_min_dist_res_to_ligand 3.60 Å**) → hydrophobic “squeeze” that can accelerate binding but not necessarily enforce a single reactive pose.
# - **Distal electrostatics:** Distal is moderately polar (**0.40**) but not strongly charged (**0.114**) → limited electrostatic correction at longer range.
# - **Distal sterics / outer size:** Outer pocket size is midrange (**mean_dist_to_centroid 9.74 Å**) with relatively high distal small-residue fraction (**0.257**) → a vestibule that may allow re-binding/reorientation after first oxidation.
# - **Phenotype & catalytic implication:** Hydrophobic packing + permissive outer shell often correlates with **high total oxidation** and **over-oxidation**. Reaction data matches: **highest total S82 yield (46.8%)** but **Di-Ox favored** (**Mono:Di 0.6**).
#
# ---
#
# ## 2A) Intra-protein variant analysis (families with variants)
#
# ### CviUPO family: CviUPO (reference) vs CviUPO-F88L+T158A
# Assumption: **CviUPO_S82_glide** is the WT/reference for the CviUPO-* constructs.
#
# **(i) Proximal electrostatics:** Variant becomes **less polar / more hydrophobic** (polar_fraction **0.385 → 0.308**; kd_weighted **1.055 → 1.4**). Mechanistic expectation: weaker H-bond pose-locking → reduced mono-selectivity, more pose diversity.
#
# **(ii) Proximal sterics:** Similar bulky fraction (both **0.615**) but **fewer close residues** (**13 → 10**) and **reactive_center_distance decreases** (**7.72 → 5.83 Å**). Mechanistic expectation: easier access to the oxidant zone (potentially higher peroxygenation rate) but with less “caging,” increasing risk of nonproductive orientations and secondary oxidation.
#
# **(iii) Distal electrostatics:** Distal becomes **less polar and less “electrostatically shaping”** (polar_fraction **0.513 → 0.485**; kd_weighted **0.387 → 0.73**). Mechanistic expectation: reduced long-range steering and potentially reduced peroxidase-like ET facilitation.
#
# **(iv) Distal sterics / outer size:** Slightly **more compact** (mean_dist_to_centroid **9.91 → 9.63 Å**) and fewer aligned residues (**39 → 33**), suggesting a less structured second shell. Mechanistic expectation: more flexibility/heterogeneity, again pushing toward permissiveness.
#
# **Net functional hypothesis:** Variant likely trades **CviUPO’s selectivity (mono bias)** for **greater reactive access**; outcome could be substrate-dependent (some substrates benefit from closer approach; others suffer from loss of polar guidance).
#
# ---
#
# ## 2B) Requested pairwise comparison: **CviUPO vs ET096**
#
# **Prox electrostatics:**
# - **CviUPO** is **more polar/charged** (charged_fraction **0.077 vs 0.0**; polar_fraction **0.385 vs 0.182**) and less hydrophobically driven (kd_weighted **1.055 vs 2.177**).
# - Mechanistic: CviUPO can **steer/lock** S82-like substrates into a productive mono-oxidation pose; ET096 is more “dry,” allowing multiple orientations.
#
# **Prox sterics:**
# - **CviUPO** is **bulkier and tighter** (mean_volume **111 vs 88 Å³**; bulky_residue_frac **0.615 vs 0.273**; median_min_dist **3.58 vs 4.33 Å**).
# - Mechanistic: CviUPO’s steric clamp suppresses re-orientation and over-oxidation; ET096’s small-residue-rich proximal shell (small_residue_frac **0.636**) is permissive.
#
# **Distal electrostatics:**
# - CviUPO distal is **more polar** (polar_fraction **0.513 vs 0.368**) and more hydrophilic (kd_weighted **0.387 vs 0.967**).
# - Mechanistic: CviUPO’s distal shell can support **substrate guidance and/or ET networks**, consistent with high ABTS.
#
# **Distal sterics / outer size:**
# - ET096 has a **larger outer pocket** (mean_dist_to_centroid **10.25 vs 9.91 Å**).
# - Mechanistic: ET096’s expanded vestibule increases binding modes and re-binding, promoting **Di-Ox**.
#
# **Reaction-data consistency:**
# - **ET096:** high total S82 (41.1) but **Di-Ox dominated** (Mono:Di 0.3) and low ABTS (0.146) → permissive, not peroxidase-like.
# - **CviUPO:** lower total S82 (23.7) but **mono-selective** (1.7) and **very high ABTS** (3.939) → pose-locking plus strong peroxidative competence.
#
# ---
#
# ## 3) Cross-protein “pocket phenotypes” (clusters) and trade-offs
#
# 1) **Open / hydrophobic / small-residue proximal (“permissive oxidizer”)**
#    - Representative: **ET096** (also partially **TE314**).
#    - Traits: low proximal charge, low-to-moderate polarity, high proximal small-residue fraction and/or larger outer pocket.
#    - Functional tendency: **high throughput** but **more over-oxidation (Di-Ox)** and more competing/unproductive events.
#
# 2) **Bulky pose-clamp with polar lining (“selective mono-oxidizer, peroxidase-capable”)**
#    - Representative: **CviUPO**.
#    - Traits: high proximal bulky fraction + higher proximal/distal polarity/charge.
#    - Functional tendency: **mono-selectivity** (better control) but can also show **high peroxidative activity** (ABTS), likely via facilitated ET/radical pathways.
#
# 3) **Reactive-center close-approach with charged distal shell (“high peroxygenation striker; bifunctional”)**
#    - Representative: **DcaUPO**.
#    - Traits: small reactive_center_distance + strong steric shaping; distal charge enriched.
#    - Functional tendency: strong peroxygenation on demanding substrates, but still **peroxidative competent**; selectivity depends on how well the substrate satisfies the close-approach geometry.
#
# 4) **Hydrophobic squeeze + permissive vestibule (“high total yield, Di-Ox drift”)**
#    - Representative: **OA167**.
#    - Traits: very hydrophobic proximal environment, bulky packing, moderate outer-pocket permissiveness.
#    - Functional tendency: **high total oxidation** with **secondary oxidation** favored.
#
# If you want, I can also (i) map the pocket_alignment_table positions onto these phenotypes (highlighting which aligned sites are likely “gatekeepers” for pose-locking vs permissiveness), and (ii) propose concrete mutation directions (e.g., add/remove distal charge; swap specific bulky proximal residues) to push each enzyme toward higher peroxygenation selectivity.
#
# === Prompt 2 Sent To LLM ===
#
# You are given:
# 1) pocket_alignment_table: filtered alignment of variable residues located within <6 Å of the ligand in at least one structure.
# 2) structural_summary_text: prior analysis summarizing proximal/distal sterics, electrostatics, and pocket phenotypes for each protein.
#
# TASK
#
# Use the alignment table together with the structural_summary_text to:
#
# 1) Identify specific residue positions that likely drive differences in:
#    - Proximal electrostatics
#    - Proximal sterics
#    - Distal steering effects
#    - Outer pocket sterics and permissiveness
#
# 2) For each key variable position:
#    - Describe residue identities across proteins.
#    - Classify substitutions as steric (small↔bulky), electrostatic (neutral↔charged), or polarity shifts.
#    - Predict mechanistic consequences (e.g., tighter cage, increased radical escape, altered substrate orientation).
#
# 3) For variants (e.g., point mutations):
#    - Explain how specific substitutions modify the previously identified pocket phenotype.
#    - Link residue-level changes to changes in reactive_center (distal)ance, local clearance, or solvent exposure.
#
# 4) Provide a short ranked list of:
#    - High-confidence mechanistic driver residues
#    - Secondary modulators
#    - Likely neutral/background mutations
#
# GUIDELINES
# - Use sequence numbering from each protein (not alignment index).
# - Explicitly tie residue-level effects back to the structural phenotypes described earlier.
# - Emphasize causal mechanistic reasoning over descriptive comparison.
# - Keep the output structured and concise.
#
# The goal is to move from global pocket phenotype to residue-level mechanistic hypotheses.
#
#
# === LLM Output 2 ===
# ## 1) Key variable positions likely driving phenotype differences (tied to prior structural summary)
#
# Below, positions are referenced in **each protein’s own numbering** (as requested). I group them by the mechanistic role they most plausibly control, based on (i) identity changes in the alignment table and (ii) the previously described pocket phenotypes (ET096 open/dry; CviUPO polar bulky clamp; DcaUPO close-approach striker with distal charge; TE314 balanced/looser cage; OA167 hydrophobic squeeze + permissive vestibule).
#
# ### A. Proximal electrostatics (pose-locking vs “dry” permissiveness)
# **Primary driver: CviUPO 165 (K) / DcaUPO 161 (C) / TE314 190 (V) / OA167 181 (A) / ET096 178 (A)**
# - This is the only clearly **charged** substitution in the provided variable set, and it sits **near the ligand** (min distances ~1.4–5.9 Å depending on structure/variant).
# - It directly matches the summary contrast: **CviUPO has more proximal electrostatic steering** than ET096/TE314/OA167 (which have ~0 proximal charge).
#
# ### B. Proximal sterics (tight clamp vs roomy microcavity; reactive approach control)
# Likely “gate/ledge” positions that change side-chain volume/shape close to the ligand:
#
# 1) **ET096 74 (V) / CviUPO 57 (L) / DcaUPO 55 (L) / TE314 77 (L) / OA167 73 (T)**
# 2) **ET096 77 (A) / CviUPO 60 (T) / DcaUPO 58 (D) / TE314 80 (T) / OA167 76 (A)**
# 3) **(ET096 gap) / CviUPO 61 (I) / DcaUPO 59 (L) / TE314 81 (L) / OA167 77 (L)**
# 4) **ET096 80 (A) / CviUPO 64 (L) / DcaUPO 62 (F) / TE314 84 (P) / OA167 80 (L)**
# These positions collectively explain “**ET096 small-biased**” vs “**CviUPO/DcaUPO bulky clamp**” vs “**TE314 looser/less bulky**” in the summary.
#
# ### C. Distal steering effects (~6–11 Å shell shaping orientation/entry)
# Positions that are not necessarily the closest contacts but can bias approach trajectories and stabilize particular poses:
#
# - **CviUPO 88 (F→L in variant) / DcaUPO 86 (L) / TE314 108 (I) / OA167 104 (I) / ET096 103 (I)**
# - **CviUPO 158 (T→A in variant) / DcaUPO 154 (F) / TE314 183 (V) / OA167 174 (P) / ET096 171 (A)**
# - **CviUPO 157 (I) / DcaUPO 153 (G) / TE314 182 (T) / OA167 173 (F)** (ET096 gap)
#
# These map well onto the summary’s “CviUPO structured polar second shell” vs “ET096 expanded vestibule / weaker steering” vs “DcaUPO distal charge/heterogeneity”.
#
# ### D. Outer pocket sterics & permissiveness (vestibule openness; re-binding/reorientation; over-oxidation propensity)
# Positions that toggle **glycine vs bulky/aromatic** or introduce rigid kinks:
#
# - **ET096 174 (L) / CviUPO 161 (G) / DcaUPO 157 (G) / TE314 186 (G) / OA167 177 (F)**
# - **ET096 223 (F) / CviUPO 210 (M) / DcaUPO 206 (L) / TE314 236 (V) / OA167 226 (I)**
# - **ET096 173 (A) / CviUPO 160 (Y) / DcaUPO 156 (L) / TE314 185 (L) / OA167 176 (Y)**
# - **ET096 227 (S) / CviUPO 214 (V) / DcaUPO 210 (M) / TE314 240 (S) / OA167 230 (T)**
#
# These are consistent with the summary’s “ET096 roomy/expanded outer pocket” and “OA167 vestibule permissiveness enabling Di-Ox drift”, while CviUPO’s architecture is more “lined/structured”.
#
# ---
#
# ## 2) Per-position residue patterns → substitution class → mechanistic consequence
#
# ### (1) Prox electrostatics “switch”: **CviUPO 165K vs others non-charged**
# - **Residues:** ET096 **178A**; CviUPO **165K**; CviUPO variant **165K**; DcaUPO **161C**; TE314 **190V**; OA167 **181A**
# - **Substitution class:** **electrostatic** (neutral → **positively charged Lys**) + polarity increase.
# - **Mechanistic consequence:**
#   - In **CviUPO**, Lys can create a **local electrostatic anchor** (direct H-bonding to heteroatoms or water-mediated networks), consistent with the summary’s **higher proximal polarity/charge** and “pose clamp” behavior (mono-selectivity, but also peroxidase-prone via ET/radical stabilization).
#   - In **ET096/TE314/OA167**, the neutral residues support the “**dry/hydrophobic**” near field → **more pose diversity** and easier **secondary oxidation** (Di-Ox).
#
# **Variant note:** CviUPO-F88L+T158A keeps **K165**, so its *loss of guidance* in the summary must come from **other polarity/steric changes**, not removal of this charge.
#
# ---
#
# ### (2) Prox steric gate: **ET096 80A vs DcaUPO 62F vs TE314 84P**
# - **Residues:** ET096 **80A**; CviUPO **64L**; variant **64L**; DcaUPO **62F**; TE314 **84P**; OA167 **80L**
# - **Substitution class:** primarily **steric** (A ↔ L/F) and **shape/rigidity** (P).
# - **Mechanistic consequence:**
#   - **ET096 A80**: small side chain → contributes to “**roomy microcavity despite contacts**”, weaker clamping, consistent with **sloppy control/Di-Ox bias**.
#   - **DcaUPO F62**: bulky aromatic “wall” → can **force a productive approach vector** and help maintain the **close reactive-center geometry** described for DcaUPO (reactive-center striker).
#   - **TE314 P84**: proline can introduce a **backbone kink/rigid turn**, often reducing conformational adaptability; here it likely creates a **different contour** rather than pure bulk, consistent with TE314’s “reactive atom close but less caging” (geometry good, but pose-locking weaker).
#
# ---
#
# ### (3) Prox polarity/charge perturbation: **DcaUPO 58D vs ET096 77A / OA167 76A**
# - **Residues:** ET096 **77A**; CviUPO **60T**; variant **60T**; DcaUPO **58D**; TE314 **80T**; OA167 **76A**
# - **Substitution class:** **electrostatic/polarity** (Asp vs A/T).
# - **Mechanistic consequence:**
#   - **DcaUPO D58** can provide a **localized negative field** that may help **orient polar substituents** or stabilize transient charge development, potentially contributing to DcaUPO’s **bifunctionality** (peroxygenation + peroxidative competence) noted in the summary.
#   - **ET096 A77 / OA167 A76** remove that capability → more purely hydrophobic/dispersion-driven packing, consistent with **higher throughput but more over-oxidation**.
#
# ---
#
# ### (4) Prox “ledge” size: **ET096 74V vs OA167 73T**
# - **Residues:** ET096 **74V**; CviUPO **57L**; DcaUPO **55L**; TE314 **77L**; OA167 **73T**
# - **Substitution class:** **steric + polarity** (T introduces OH).
# - **Mechanistic consequence:**
#   - **OA167 T73** adds a polar OH at a position where others are hydrophobic (V/L). In a globally hydrophobic OA167 pocket (summary: very nonpolar near-field), this single OH is more likely to act as a **weak orienting contact** than to make the pocket “polar”. It may help **initial capture** but not enforce a single pose—consistent with OA167’s **high total oxidation + Di-Ox drift**.
#
# ---
#
# ### (5) Distal steering / clamp tuning: **CviUPO 88F → (variant) 88L**
# - **Residues:** ET096 **103I**; CviUPO **88F**; variant **88L**; DcaUPO **86L**; TE314 **108I**; OA167 **104I**
# - **Substitution class:** **steric/aromaticity** (Phe → Leu; loss of π surface).
# - **Mechanistic consequence:**
#   - **WT CviUPO F88**: aromatic face can provide **π-stacking / edge-to-face** interactions that “**pose-lock**” aromatic substrates/intermediates—fits the summary’s selective mono-oxidizer clamp.
#   - **F88L**: reduces aromatic steering and slightly reduces effective bulk/shape complementarity → **loosens the clamp**, consistent with the summary’s “more permissive hydrophobic binding” and reduced electrostatic shaping (because aromatic packing often cooperates with polar networks by fixing pose).
#
# ---
#
# ### (6) Distal/outer-shell permissiveness: **Gly vs bulky at the “hinge”: CviUPO 161G / DcaUPO 157G / TE314 186G vs ET096 174L vs OA167 177F**
# - **Residues:** ET096 **174L**; CviUPO **161G**; variant **161G**; DcaUPO **157G**; TE314 **186G**; OA167 **177F**
# - **Substitution class:** strongly **steric** (G ↔ L/F) and **flexibility** (G increases backbone freedom).
# - **Mechanistic consequence:**
#   - **Gly (Cvi/Dca/TE314)**: can create a **more permissive hinge/turn** that allows subtle backbone accommodation while still maintaining a lined pocket (especially in CviUPO’s “structured second shell”).
#   - **ET096 L174**: adds bulk where others have Gly → could locally narrow, but in ET096’s overall small-residue-rich context this may instead create a **single hydrophobic contact** without true clamping (net still “open”).
#   - **OA167 F177**: bulky aromatic at this site can create a **hydrophobic squeeze point**; combined with OA167’s permissive vestibule (summary), this can promote **fast binding** but not necessarily prevent **post-first-oxidation reorientation**, enabling Di-Ox.
#
# ---
#
# ### (7) Outer pocket “lining” hydrophobe: **ET096 223F vs TE314 236V vs OA167 226I**
# - **Residues:** ET096 **223F**; CviUPO **210M**; DcaUPO **206L**; TE314 **236V**; OA167 **226I**
# - **Substitution class:** **steric/hydrophobic packing** (F bulkier/aromatic vs aliphatic).
# - **Mechanistic consequence:**
#   - **ET096 F223** can create a **hydrophobic landing pad** in the outer pocket, supporting the summary’s “expanded vestibule admits multiple poses” by stabilizing multiple nonpolar orientations (dispersion-driven). This aligns with ET096’s **high total oxidation + strong Di-Ox bias**.
#
# ---
#
# ## 3) Variant-specific mechanistic explanation (CviUPO-F88L + T158A)
#
# ### Variant site 1: **CviUPO 88 F → L**
# - **Effect type:** steric/aromaticity loss (π interactions removed).
# - **Phenotype shift:** from “**pose-locking clamp**” toward **more permissive hydrophobic packing**.
# - **Mechanistic link to summary metrics:** fewer/less specific contacts can increase **pose diversity**, consistent with the summary’s inferred reduction in “electrostatic guidance” even though charge count is unchanged.
#
# ### Variant site 2: **CviUPO 158 T → A**
# - **Residues at this aligned position:** ET096 **171A**; CviUPO **158T**; variant **158A**; DcaUPO **154F**; TE314 **183V**; OA167 **174P**
# - **Effect type:** **polarity decrease** (removes OH) + slight steric decrease.
# - **Mechanistic consequence:**
#   - Removes a potential **H-bond handle** in the distal/second-shell region → weaker **distal steering**, matching the summary’s “distal becomes less polar/less shaping”.
#   - Can also increase **local clearance** and reduce “clamp density”, consistent with the summary’s observation of fewer close residues and a more permissive architecture.
#
# ### Net variant hypothesis (explicitly tied to summary)
# - **Reactive-center distance decreases strongly** in the variant (summary: 7.72 → 5.83 Å): the mutations likely allow the ligand to **sit deeper/closer** (less steric/aromatic blocking + less H-bond-defined positioning).
# - But because both changes reduce **pose-locking specificity**, the closer approach may come with **higher probability of misorientation** and **secondary oxidation** (Di-Ox risk), especially for substrates that benefited from F88 π-guidance and T158 H-bond steering.
#
# ---
#
# ## 4) Ranked residue list (mechanistic drivers vs modulators vs likely neutral)
#
# ### High-confidence mechanistic driver residues (most causal)
# 1) **CviUPO 165K** (vs neutral at aligned site): proximal electrostatic anchor → explains CviUPO’s stronger steering/pose-locking and peroxidase-prone behavior.
# 2) **CviUPO 88F (→L in variant)**: aromatic clamp/steering element; its removal directly matches “loosened clamp” phenotype.
# 3) **DcaUPO 62F** (vs ET096 80A / TE314 84P): bulky proximal wall consistent with DcaUPO’s strong steric shaping and productive close-approach behavior.
# 4) **DcaUPO 58D** (vs A/T): localized negative electrostatics near pocket—plausible contributor to DcaUPO’s distinct distal/prox electrostatic management and bifunctionality.
#
# ### Secondary modulators (context-dependent, tune permissiveness/outer pocket)
# - **ET096 223F** (outer hydrophobe): stabilizes multiple outer-pocket poses → supports ET096 permissiveness/Di-Ox.
# - **ET096 174L vs Gly in others / OA167 177F**: outer-pocket hinge/neck shaping; likely tunes re-binding/reorientation propensity.
# - **OA167 73T**: isolated proximal OH in otherwise hydrophobic pocket; may weakly bias entry/orientation.
#
# ### Likely neutral/background (within this limited table; smaller expected effect alone)
# - **ET096 172S / CviUPO 159S / TE314 184S / OA167 175T / DcaUPO 155G**: mostly small/polar swaps at relatively larger distances in several structures—likely fine-tuning rather than primary phenotype drivers.
# - **ET096 227S vs TE314 240S vs OA167 230T**: conservative polarity; probably minor unless coupled to local geometry changes.
#
# If you want, I can reformat this into a per-protein “mutation playbook” (what to mutate in ET096 to mimic CviUPO’s clamp; what to mutate in OA167 to reduce Di-Ox drift; etc.) using only positions present in this alignment table.
# PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_llm_analysis.md')

# %% [markdown]
# ## Save Thread Update
# Run this final cell to append run metadata and prompt context to `chats/<thread_id>.json`.

# %%
persist_thread_update(
    root_key=root_key,
    thread_id=thread_id,
    user_inputs=user_inputs,
    input_paths=input_paths,
    selected_positions=selected_positions,
    reaction_df=reaction_df,
    out_interp=out_interp,
    out_patterns=out_patterns,
    llm_analysis_path=out_llm,
    llm_analysis_text=llm_analysis,
    llm_model=str(user_inputs.get("llm_model", "")),
)
# Out:
# '2026-02-11T11:40:30.647192+00:00'
