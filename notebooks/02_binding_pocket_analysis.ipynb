# %% [markdown]
# # 02 - Binding Pocket Analysis
#
# Notebook UI for UPO homolog pocket analysis using an LLM with binding, alignment, and optional reaction inputs.

# %% [markdown]
# ## Python Path Setup
# Ensure project-root imports work whether Jupyter starts from repo root or `notebooks/`.

# %%
from pathlib import Path
import os
import sys

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
src_root = repo_root / "src"
if src_root.exists() and str(src_root) not in sys.path:
    sys.path.insert(0, str(src_root))

# %% [markdown]
# ## Imports
# Load helper functions for table loading, LLM analysis, output export, and thread persistence.

# %%
import importlib
import agentic_protein_design.steps.binding_pocket as bp
bp = importlib.reload(bp)
from project_config.local_api_keys import OPENAI_API_KEY

analyze_pocket_profiles = bp.analyze_pocket_profiles
default_user_inputs = bp.default_user_inputs
build_prompt_with_context = bp.build_prompt_with_context
generate_llm_pocket_analysis = bp.generate_llm_pocket_analysis
init_thread = bp.init_thread
load_input_tables = bp.load_input_tables
persist_thread_update = bp.persist_thread_update
save_binding_outputs = bp.save_binding_outputs
save_llm_analysis = bp.save_llm_analysis
setup_data_root = bp.setup_data_root

# %% [markdown]
# ## API Key Setup
# Load the OpenAI key from `project_config/local_api_keys.py` into environment variables for LLM calls.

# %%
if OPENAI_API_KEY and OPENAI_API_KEY != "REPLACE_WITH_YOUR_OPENAI_API_KEY":
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

"OPENAI_API_KEY" in os.environ
# Out:
# True

# %% [markdown]
# ## User Inputs
# Edit all run parameters here (single place): dataset root, thread selection, analysis options, model, and input paths.

# %%
root_key = "PIPS2"
existing_thread_id = "59353c876ab140688b1c239a15aac24e"# None

user_inputs = {
    "selected_positions": None, # [100, 103, 104, 107, 141, 222],
    "pairwise_comparisons":  [("CviUPO", "ET096")], # None
    "focus_question": (
        "Identify per-protein structural interpretations and cross-homolog patterns "
        "that could explain activity/property differences."
    ),
    "reaction_data_description": (
        "- Veratryl alcohol: peroxygenative\n"
        "- Naphthalene: peroxygenative\n"
        "- NBD: peroxygenative\n"
        "- ABTS: peroxidative\n"
        "- S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased\n"
        "Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance."
    ),
    "use_reaction_data": True,
    "llm_model": "gpt-5.2",
    "llm_temperature": 0.2,
    "llm_max_rows_per_table": 300,
}

input_paths = {
    # Paths are relative to the data root from project_config.variables.address_dict[root_key].
    "binding_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv",
    "alignment_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv",
    "reaction_data_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv",
}

# Optional: reset analysis options from helper defaults
# user_inputs = default_user_inputs()

# %% [markdown]
# ## Setup Runtime Context
# Initialize data directories and active chat thread from the values above.

# %%
data_root, resolved_dirs = setup_data_root(root_key)
thread, threads_preview = init_thread(root_key, existing_thread_id)
thread_id = thread["thread_id"]
data_root, thread_id
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data'),
#  '59353c876ab140688b1c239a15aac24e')

# %% [markdown]
# ## Load Input Tables
# Load descriptor and alignment tables, and optional reaction data, from `input_paths`.

# %%
def resolve_input_path(path_value: str) -> Path:
    p = Path(path_value).expanduser()
    if p.is_absolute():
        return p.resolve()
    return (data_root / p).resolve()

binding_csv = resolve_input_path(input_paths["binding_csv"])
alignment_csv = resolve_input_path(input_paths["alignment_csv"])
reaction_data_csv = None
if user_inputs.get("use_reaction_data", False) and input_paths.get("reaction_data_csv", "").strip():
    reaction_data_csv = resolve_input_path(input_paths["reaction_data_csv"])

pocket, ali, reaction_df = load_input_tables(binding_csv, alignment_csv, reaction_data_csv)
binding_csv, alignment_csv, reaction_data_csv, pocket.head(3), (None if reaction_df is None else reaction_df.head(3))
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv'),
#     Unnamed: 0                    struct_name                  struct_name.1  \
#  0           0                ET096_S82_glide                ET096_S82_glide
#  1           1               CviUPO_S82_glide               CviUPO_S82_glide
#  2           2  CviUPO-F88L+T158A_S82_chai1_0  CviUPO-F88L+T158A_S82_chai1_0
#
#                     struct_name.2  num_pocket_res_ali  num_pocket_res<6  \
#  0                ET096_S82_glide                  38                12
#  1               CviUPO_S82_glide                  39                13
#  2  CviUPO-F88L+T158A_S82_chai1_0                  33                10
#
#     reactive_center_distance  median_dist_res_to_ligand_reactive_center  \
#  0                     7.095                                      7.921
#  1                     7.720                                      6.683
#  2                     5.827                                      6.922
#
#     median_min_dist_res_to_ligand  mean_min_dist_to_centroid (distal)  ...  \
#  0                          4.330                               8.570  ...
#  1                          3.575                               8.079  ...
#  2                          4.155                               7.691  ...
#
#     kd_weighted (distal)  kd_weighted (proximal)  hw_mean (distal)  \
#  0                 0.967                   2.177            -0.466
#  1                 0.387                   1.055            -0.546
#  2                 0.730                   1.400            -0.658
#
#     hw_mean (proximal)  hw_weighted (distal)  hw_weighted (proximal)  \
#  0              -0.864                -0.464                  -0.940
#  1              -0.946                -0.475                  -0.825
#  2              -0.900                -0.533                  -0.792
#
#     charged_fraction (distal)  charged_fraction (proximal)  \
#  0                      0.132                        0.000
#  1                      0.128                        0.077
#  2                      0.121                        0.077
#
#     polar_fraction (distal)  polar_fraction (proximal)
#  0                    0.368                      0.182
#  1                    0.513                      0.385
#  2                    0.485                      0.308
#
#  [3 rows x 41 columns],
#    UPO Homologs  Veratryl alcohol (peroxygenation)  \
#  0        ET096                              0.597
#  1       CviUPO                              0.333
#  2       DcaUPO                              1.558
#
#     Naphthalene (peroxygenation)  NBD (peroxygenation)  ABTS (peroxidation)  \
#  0                         0.127                 0.053                0.146
#  1                         0.168                 0.169                3.939
#  2                         0.136                 1.242                2.700
#
#     S82 Mono-Ox %yield  S82 Di-Ox % Yield  S82 Total % Yield  S82 Mono:Di Ratio
#  0                 8.4               32.7               41.1                0.3
#  1                14.8                8.9               23.7                1.7
#  2                10.0                6.2               16.2                1.6  )

# %% [markdown]
# ## Structured Exports
# Generate heuristic comparative tables and export CSVs to `processed/`.

# %%
selected_positions = user_inputs["selected_positions"]
interp_df, pattern_summary = analyze_pocket_profiles(pocket, ali, selected_positions)
out_interp, out_patterns = save_binding_outputs(interp_df, pattern_summary, resolved_dirs["processed"])
out_interp, out_patterns
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_interpretations.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_pattern_summary.csv'))

# %% [markdown]
# ## LLM Pocket Analysis
# Query the LLM client with the full prompt and input tables, then save markdown output.
#
# Prerequisite: set `OPENAI_API_KEY` in `project_config/local_api_keys.py`.

# %%
# Run two-stage LLM analysis (the helper prints Prompt 1/2 and Output 1/2)
llm_analysis = generate_llm_pocket_analysis(pocket, ali, reaction_df, user_inputs)
out_llm = save_llm_analysis(llm_analysis, resolved_dirs["processed"])
out_llm
# Out:
# === Prompt 1 Sent To LLM ===
#
# Analyse the uploaded inputs for a set of proteins to interpret how binding-pocket structure relates to catalytic activity and selectivity.
# Consider how both the proximal (<6 Å from docked ligand) and distal (up to ~11 Å from binding pocket centroid) residues affect the binding pocket environment.
#
# INPUTS
# - binding_pocket_table: extracted binding-pocket properties (per protein), calculated separately over proximal and distal residue sets where available.
# - pocket_alignment_table: filtered residue alignment of pocket-proximal positions.
# - reaction_data (optional): enzyme activity data on substrates.
#
# OBJECTIVE
# For each protein, integrate structural descriptors with (optional) reaction data to infer mechanistic behavior and classify pocket phenotypes.
#
# TASKS
#
# 1) For each protein:
#    - Generate a punchy tagline.
#    - Provide a concise 5-6 bullet summary addressing:
#         (i) proximal electrostatics
#         (ii) proximal sterics
#         (iii) distal electrostatics
#         (iv) distal sterics / outer pocket size
#         (v) overall synthesis of pocket phenotype, integrating structural properties with catalytic implications:
#             - Interpret how geometry and chemistry influence productive (peroxygenative) vs competing (peroxidative) pathways.
#             - If reaction_data is provided, use it to support structure–function relationships.
#
#    Use the following column groups:
#
#    PROXIMAL ELECTROSTATICS
#    - charged_fraction (proximal), polar_fraction (proximal)
#    - kd_weighted (proximal), hw_weighted (proximal)
#    - median_dist_res_to_ligand_reactive_center
#
#    PROXIMAL STERICS
#    - mean_volume (proximal), weighted_mean_volume (proximal)
#    - volume_variance (proximal)
#    - small_residue_frac (proximal), bulky_residue_frac (proximal)
#    - median_min_dist_res_to_ligand
#    - reactive_center_distance
#    - num_pocket_res_lt6
#
#    DISTAL ELECTROSTATICS
#    - charged_fraction (distal), polar_fraction (distal)
#    - kd_weighted (distal), hw_weighted (distal)
#
#    DISTAL STERICS / OUTER POCKET SIZE
#    - mean_dist_to_centroid
#    - mean_min_dist_to_centroid
#    - mean_dist_backbone_to_centroid
#    - mean_volume (distal)
#    - volume_variance (distal)
#    - small_residue_frac (distal), bulky_residue_frac (distal)
#    - num_pocket_res_ali
#
#    If proximal/distal suffixes are not explicitly present, infer proximal/distal groupings from context and state your assumption briefly.
#
# 2) Comparative analysis requirements (do BOTH):
#    A) Intra-protein variant analysis (MANDATORY when variants are present):
#    - Detect proteins that share the same base protein identity but differ by variant/mutation labels.
#    - For each such protein family, explicitly compare each variant against its WT/reference form (if WT/reference is present).
#    - If WT is not explicitly labeled, infer the closest reference sequence in that family and state the assumption.
#    - For each variant-vs-reference comparison, report which structural dimensions changed:
#         (i) proximal electrostatics
#         (ii) proximal sterics
#         (iii) distal electrostatics
#         (iv) distal sterics / outer pocket size
#    - Provide a mechanistic rationale linking those differences to functional shifts.
#
#    B) User-requested pairwise comparisons:
#    - Pairwise comparisons requested: CviUPO vs ET096
#    - Perform each requested pairwise comparison in addition to section A.
#    - Explicitly contrast which structural dimensions changed (prox electrostatics, prox sterics, distal electrostatics, distal sterics).
#    - Provide a mechanistic rationale for functional shifts.
#
# 3) Distill cross-protein trends or clusters (“pocket phenotypes”):
#    - Identify recurring structural archetypes (e.g., tight/polar pose-locking vs open/hydrophobic permissive).
#    - Link clusters to turnover vs selectivity trade-offs.
#
# OUTPUT STYLE
# - Clear, human-interpretable, mechanistically grounded.
# - Emphasize intuition over raw numbers.
# - Keep summaries compact and comparative.
#
#
# REACTION CONTEXT (OPTIONAL)
# - Veratryl alcohol: peroxygenative
# - Naphthalene: peroxygenative
# - NBD: peroxygenative
# - ABTS: peroxidative
# - S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased
# Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance.
#
# REACTION_DATA_STATUS: provided. Rows=5, Columns=['UPO Homologs', 'Veratryl alcohol (peroxygenation)', 'Naphthalene (peroxygenation)', 'NBD (peroxygenation)', 'ABTS (peroxidation)', 'S82 Mono-Ox %yield', 'S82 Di-Ox % Yield', 'S82 Total % Yield', 'S82 Mono:Di Ratio']
#
# === LLM Output 1 ===
# ## Per-protein pocket interpretations (proximal <6 Å; distal ~6–11 Å)
#
# ### ET096_S82_glide — **“Small, dry inner pocket; roomy outer shell → oxidation-prone generalist.”**
# - **Prox electrostatics:** Essentially *uncharged* (charged_fraction 0.0) and low polar (0.182) with relatively high hydropathy (kd_weighted 2.18; hw_weighted −0.94) → weak pose-locking via H-bonds/salt bridges; favors hydrophobic binding modes.
# - **Prox sterics:** Many close contacts (num_pocket_res<6 = 12) but **small-residue rich** (small_residue_frac 0.636; bulky 0.273) → “soft” steric definition: lots of atoms nearby, but not many bulky walls to enforce a single reactive pose. Reactive center sits **farther** from catalytic locus (reactive_center_distance 7.10 Å).
# - **Distal electrostatics:** Some charge/polarity appears only distally (charged 0.132; polar 0.368) but still moderately hydrophobic overall (kd_weighted 0.97).
# - **Distal sterics / outer size:** Distal centroid distances are the **largest in the set** (mean_dist_to_centroid 10.25; mean_min_dist_to_centroid 8.57) → a more open “outer vestibule” that can admit multiple poses/solvent.
# - **Phenotype synthesis (mechanistic):** A hydrophobic, weakly polar proximal environment plus a roomy outer pocket tends to allow **multiple binding geometries** and easier solvent access—conditions that often increase **off-pathway/peroxidative** events and over-oxidation.
#   **Reaction support:** ET096 shows **low S82 Mono:Di (0.3)** with high Di-Ox (32.7%) and modest ABTS (0.146): consistent with poor pose control near the reactive center and a permissive pocket that enables repeated oxidation.
#
# ---
#
# ### CviUPO_S82_glide — **“Bulky, polar, and closer-in → pose-locking mono-oxidizer (but peroxidase-capable).”**
# - **Prox electrostatics:** More **polar and partially charged** (polar 0.385; charged 0.077) than ET096; still hydrophobic but less extreme (kd_weighted 1.06; hw_weighted −0.83). Median residue-to-reactive-center distance is **shorter** (6.68 Å) → tighter chemical control around the reactive locus.
# - **Prox sterics:** **Bulky-lined inner pocket** (bulky_residue_frac 0.615; small 0.154) with the **closest ligand approach** in the set (median_min_dist_res_to_ligand 3.58 Å) and many proximal residues (13) → strong geometric constraint/pose definition.
# - **Distal electrostatics:** Distal region is notably **polar** (polar 0.513) with moderate charge (0.128) → can stabilize ingress/egress states and influence H2O2/water organization.
# - **Distal sterics / outer size:** Outer pocket is not especially expanded (mean_dist_to_centroid 9.91; mean_min_dist_to_centroid 8.08) → less “extra space” for alternative poses than ET096.
# - **Phenotype synthesis (mechanistic):** Bulky + polar proximal residues tend to **lock a productive orientation** for single oxygen transfer (peroxygenation-like behavior on S82), but the higher distal polarity/charge can also support **electron-transfer/peroxidase** chemistry (substrate radical formation) when suitable donors bind.
#   **Reaction support:** CviUPO has **high ABTS (3.939)** (peroxidative competence) yet **S82 Mono:Di = 1.7** (mono favored), consistent with good pose control for S82 but an electrostatically supportive environment for peroxidative substrates like ABTS.
#
# ---
#
# ### CviUPO-F88L+T158A_S82_chai1_0 — **“CviUPO opened and de-aromatized: closer reactive approach, slightly less polar clamp.”**
# *(Variant family: CviUPO; reference assumed = CviUPO_S82_glide because it is the unmutated homolog in the table.)*
# - **Prox electrostatics:** Similar charge (charged 0.077) but **lower polarity** (polar 0.308 vs 0.385) and **more hydrophobic** proximal tendency (kd_weighted 1.40 vs 1.06) → weaker H-bond “clamp” than WT.
# - **Prox sterics:** Still **bulky-dominated** (bulky 0.615), but reactive center is **closer** (reactive_center_distance 5.83 Å vs 7.72 Å) and fewer proximal residues (10 vs 13) → fewer constraints but potentially more direct access to the reactive locus.
# - **Distal electrostatics:** Distal polarity slightly reduced (0.485 vs 0.513) and kd_weighted increases (0.73 vs 0.39) → distal region becomes less hydrophilic/less “electrostatic funnel.”
# - **Distal sterics / outer size:** Slightly **more compact** outer pocket (mean_dist_to_centroid 9.63 vs 9.91; mean_min_dist_to_centroid 7.69 vs 8.08) with fewer aligned pocket residues (33 vs 39) → could reflect local remodeling/loop shifts.
# - **Phenotype synthesis (mechanistic):** F88L removes an aromatic “wall” and T158A removes a polar sidechain: net effect is typically **reduced pose-locking polarity** but **improved approach geometry** to the reactive center. Mechanistically, this can increase turnover for some substrates (better access) while risking more pose diversity (selectivity loss) depending on substrate shape.
#   **Reaction_data:** not provided for this variant, so this is a structure-based inference.
#
# ---
#
# ### DcaUPO_S82_glide — **“Reactive-center proximity with a dry inner pocket → fast oxygen transfer, moderate over-oxidation control.”**
# - **Prox electrostatics:** Low proximal polarity (0.154) with some charge (0.077) and high hydropathy (kd_weighted 1.79; hw_weighted −1.04) → chemically “dry” near the ligand, favoring hydrophobic packing over H-bond steering.
# - **Prox sterics:** Very **bulky proximal lining** (bulky 0.615) and the **closest reactive-center distance among measured homologs** (4.93 Å) with the **most proximal residues** (15) → strong confinement *and* close approach to the reactive locus.
# - **Distal electrostatics:** Distal region is the **most charged** here (charged 0.20) with moderate polarity (0.40) → can tune access channel electrostatics and stabilize polar intermediates/solvent networks.
# - **Distal sterics / outer size:** Outer pocket size is mid-range (mean_dist_to_centroid 10.00; mean_min_dist_to_centroid 8.20). Proximal volume variance is **very high** (1183) → suggests heterogeneous steric landscape: tight spots plus small voids that can bias regioselectivity.
# - **Phenotype synthesis (mechanistic):** Close reactive approach + bulky confinement supports **productive peroxygenative oxygen transfer** (good alignment for HAT/O-insertion), while the dry proximal environment can reduce unproductive polar interactions. Distal charge may still enable peroxidative chemistry with appropriate donors.
#   **Reaction support:** High peroxygenative activities (Veratryl alcohol 1.558; NBD 1.242) and **Mono:Di = 1.6** (mono favored) fit a “productive, pose-constraining” pocket; ABTS is also high (2.7), consistent with distal electrostatics supporting peroxidative turnover too.
#
# ---
#
# ### TE314_S82_chai1_0 — **“Balanced pocket with moderate polarity → mixed control, di-oxidation still accessible.”**
# - **Prox electrostatics:** Uncharged proximal set (charged 0.0) but **moderately polar** (0.308) and moderately hydrophobic (kd_weighted 1.82; hw_weighted −0.89) → some H-bonding possible without strong ionic steering.
# - **Prox sterics:** More “average” sterics (bulky 0.308; small 0.231) and relatively small proximal volumes (mean 98.5) → less of a hard steric clamp than CviUPO/DcaUPO. Reactive center is **close** (4.08 Å) which can promote turnover even without extreme confinement.
# - **Distal electrostatics:** Distal is moderately polar (0.371) and fairly hydrophobic (kd_weighted 1.43) → not a strongly electrostatic access channel.
# - **Distal sterics / outer size:** Distal centroid distances are on the compact side (mean_dist_to_centroid 9.73; mean_min_dist_to_centroid 7.86) → less outer-pocket “breathing room.”
# - **Phenotype synthesis (mechanistic):** Close reactive approach supports oxidation, but the lack of a strong bulky/polar proximal clamp can allow **re-binding/reorientation**, enabling **more di-oxidation** than the mono-selective enzymes.
#   **Reaction support:** **Mono:Di = 0.7** with substantial Di-Ox (21.5%) is consistent with moderate pose control and accessible second-oxidation trajectories.
#
# ---
#
# ### OA167_S82_swissdock_0 — **“Hydrophobic, bulky inner pocket with a permissive outer region → high total oxidation, modest mono selectivity.”**
# - **Prox electrostatics:** Uncharged proximal (0.0) but moderately polar (0.308) and **very hydrophobic** (kd_weighted 1.41; hw_weighted −1.36, most negative) → strong hydrophobic driving force, limited electrostatic steering.
# - **Prox sterics:** Bulky proximal lining (bulky 0.538; small 0.154) with high proximal volume (mean 108.5; weighted 111.1) → can bind hydrophobic substrates tightly but not necessarily enforce a single reactive pose if the cavity is large.
# - **Distal electrostatics:** Moderate polarity/charge (polar 0.40; charged 0.114) with kd_weighted 1.03 → neither strongly hydrophilic nor strongly ionic distally.
# - **Distal sterics / outer size:** Outer pocket is mid-sized (mean_dist_to_centroid 9.74; mean_min_dist_to_centroid 8.08). Fewer proximal residues (10) suggests less “contact-rich” pose locking than CviUPO/DcaUPO.
# - **Phenotype synthesis (mechanistic):** Hydrophobic + bulky proximal residues can promote binding and turnover (high total yield), but limited electrostatic steering and a relatively permissive architecture can allow **multiple oxidation events**.
#   **Reaction support:** Highest **S82 total yield (46.8%)** but **Mono:Di = 0.6** (di favored), matching a “high-throughput, less selective” oxidation pocket.
#
# ---
#
# ## 2A) Intra-protein variant analysis (families with variants)
#
# ### Family: **CviUPO (WT/reference) vs CviUPO-F88L+T158A**
# **Reference assumption:** CviUPO_S82_glide is WT-like reference (unlabeled, but matches base name “CviUPO”).
#
# **Changes in structural dimensions (variant vs reference):**
# - **(i) Prox electrostatics:** **↓ polarity** (0.385 → 0.308) and **↑ hydrophobicity** (kd_weighted 1.06 → 1.40). Charge unchanged (0.077).
# - **(ii) Prox sterics:** **↓ contact richness** (num<6: 13 → 10) and **reactive center moves closer** (7.72 → 5.83 Å). Bulky fraction stays high (0.615).
# - **(iii) Distal electrostatics:** Slight **↓ polarity** (0.513 → 0.485) and **↑ hydrophobicity** (kd_weighted 0.39 → 0.73).
# - **(iv) Distal sterics / outer size:** Slight **compaction** (mean_dist_to_centroid 9.91 → 9.63; mean_min_dist_to_centroid 8.08 → 7.69) and fewer aligned pocket residues (39 → 33).
#
# **Mechanistic rationale:** Removing an aromatic sidechain at 88 (F→L) and a polar sidechain at 158 (T→A) plausibly **reduces polar anchoring and aromatic stacking**, increasing conformational/pose freedom, while the geometry shift (shorter reactive_center_distance) can **improve direct access/alignment** for oxygen transfer. Net expectation: potentially higher turnover on some hydrophobes but **risk of reduced selectivity** (more alternative poses) unless the remaining bulky framework still constrains orientation.
#
# ---
#
# ## 2B) User-requested pairwise comparison: **CviUPO vs ET096**
#
# ### CviUPO_S82_glide **vs** ET096_S82_glide
# **(i) Prox electrostatics:**
# - CviUPO is **more polar/charged** (polar 0.385; charged 0.077) vs ET096 (polar 0.182; charged 0.0).
# - ET096 is **more hydrophobic** proximally (kd_weighted 2.18 vs 1.06).
# **Implication:** CviUPO should better **pose-lock** via polar contacts; ET096 relies on hydrophobics and is more permissive.
#
# **(ii) Prox sterics:**
# - CviUPO is **much bulkier** proximally (bulky 0.615; small 0.154) vs ET096 (bulky 0.273; small 0.636).
# - CviUPO has slightly more proximal residues (13 vs 12) and closer closest-contact (median_min_dist 3.58 vs 4.33).
# **Implication:** CviUPO provides a **hard steric mold**; ET096 provides a **soft, small-residue-lined** cavity that tolerates multiple orientations.
#
# **(iii) Distal electrostatics:**
# - CviUPO distal region is **more polar** (0.513 vs 0.368) and less hydrophobic (kd_weighted 0.39 vs 0.97).
# **Implication:** CviUPO likely has a more electrostatically “organized” access channel that can support peroxidative ET with donors (e.g., ABTS).
#
# **(iv) Distal sterics / outer pocket size:**
# - ET096 has a **more expanded outer pocket** (mean_dist_to_centroid 10.25 vs 9.91; mean_min_dist_to_centroid 8.57 vs 8.08).
# **Implication:** ET096 more readily accommodates alternative binding modes and solvent—often increasing **over-oxidation** and competing pathways.
#
# **Functional/mechanistic read-through (supported by reaction data):**
# - **ET096:** very low **Mono:Di (0.3)** and high Di-Ox → consistent with permissive, hydrophobic, outer-open pocket enabling reorientation and second oxidation. Low ABTS suggests less favorable peroxidative ET environment despite openness.
# - **CviUPO:** **Mono:Di (1.7)** indicates better mono selectivity, consistent with bulky/polar proximal pose-locking; **high ABTS (3.939)** aligns with its more polar/charged distal environment supporting peroxidative turnover.
#
# ---
#
# ## 3) Cross-protein “pocket phenotypes” (recurring archetypes)
#
# 1) **Pose-locking mono-oxidizers (bulky + polar proximal; moderately constrained outer pocket)**
#    - Prototype: **CviUPO**, **DcaUPO** (though DcaUPO is less polar proximally, it is strongly confining and close-in).
#    - Expected behavior: higher probability of **productive peroxygenative alignment** and higher **Mono:Di** on S82; can still show peroxidative activity if distal electrostatics support ET (notably DcaUPO, CviUPO).
#
# 2) **Permissive/open oxidizers (small-residue proximal and/or expanded distal vestibule)**
#    - Prototype: **ET096** (small-residue proximal + largest distal expansion).
#    - Expected behavior: higher **over-oxidation/Di-Ox**, more mixed binding modes; selectivity suffers (low Mono:Di).
#
# 3) **Hydrophobic throughput pockets (bulky + hydrophobic proximal, moderate outer size, limited electrostatic steering)**
#    - Prototype: **OA167**.
#    - Expected behavior: strong binding/turnover on hydrophobes (high total yield) but **modest mono selectivity** (Mono:Di < 1) due to limited polar pose constraints.
#
# 4) **Balanced/middle-ground pockets (moderate polarity and moderate steric definition)**
#    - Prototype: **TE314**.
#    - Expected behavior: decent activity with **mixed selectivity**, allowing di-oxidation pathways when the substrate can rebind/reorient.
#
# If you want, I can also (i) map the **specific aligned proximal positions** that most differentiate CviUPO vs ET096 (from the pocket_alignment_table) into “likely gating/pose-locking residues”, and (ii) propose concrete mutation directions to shift a given enzyme toward mono-selective peroxygenation vs peroxidation.
#
# === Prompt 2 Sent To LLM ===
#
# You are given:
# 1) pocket_alignment_table: filtered alignment of variable residues located within <6 Å of the ligand in at least one structure.
# 2) structural_summary_text: prior analysis summarizing proximal/distal sterics, electrostatics, and pocket phenotypes for each protein.
#
# TASK
#
# Use the alignment table together with the structural_summary_text to:
#
# 1) Identify specific residue positions that likely drive differences in electrostatics and /or sterics. For each key variable position:
#    - Describe residue identities across proteins.
#    - Classify substitutions as steric (small↔bulky), electrostatic (neutral↔charged), or polarity shifts.
#    - Predict mechanistic consequences (e.g., tighter cage, increased radical escape, altered substrate orientation).
#    - Specifically contrast the effect of point mutations in variants of the same base sequence.
#      Explain how the mutations modify the previously identified pocket environment and its chemistry.
#
# 2) Provide a short ranked list of:
#    - High-confidence mechanistic driver residues
#    - Secondary modulators
#    - Likely neutral/background mutations
#
# GUIDELINES
# - Use sequence numbering from each protein (not alignment index).
# - Explicitly tie residue-level effects back to the structural phenotypes described earlier.
# - Emphasize causal mechanistic reasoning over descriptive comparison.
# - Keep the output structured and concise.
#
# The goal is to move from global pocket phenotype to residue-level mechanistic hypotheses.
#
#
# === LLM Output 2 ===
# ## 1) Key variable pocket positions → steric/electrostatic drivers (tied to prior phenotypes)
#
# ### A. **CviUPO position 88 (WT F88) / variant L88**  *(alignment row index 141)*
# - **Residues across proteins (their own numbering):**
#   - **ET096 I103**, **CviUPO F88**, **CviUPO-F88L+T158A L88**, **DcaUPO L86**, **TE314 I108**, **OA167 I104**
# - **Substitution class:** primarily **steric + polarity** (aromatic → aliphatic).
#   - **F (bulky aromatic, polarizable π)** → **L/I (bulky aliphatic, less polarizable)**
# - **Mechanistic consequence (causal):**
#   - In **CviUPO WT**, **F88** is a classic *aromatic wall* that can (i) **tighten the inner cage** and (ii) provide **π/dispersion “pose-locking”** against hydrophobic substrate faces. This matches the earlier phenotype: **bulky, polar, closer-in → strong geometric constraint and mono-selectivity**.
#   - In the **F88L variant**, removing aromaticity should **reduce rigid packing/stacking constraints** and **decrease local polarity/polarizability**, consistent with the observed global shift in the summary (**↓prox polarity, ↑hydrophobicity, ↓contact richness**). Net: **more pose diversity** and potentially **more radical escape/rebinding trajectories** (i.e., easier access to di-oxidation paths) *unless* the closer reactive approach dominates for a given substrate.
# - **Variant-specific contrast (same base sequence):**
#   - **CviUPO F88 → L88** directly implements the summary’s “**de-aromatized**” pocket: weaker “clamp” but potentially **less steric frustration** for approach, helping explain the variant’s **shorter reactive_center_distance** (structure-level consequence).
#
# **Confidence:** high (directly mutated; matches the “pose-locking vs opened” narrative).
#
# ---
#
# ### B. **CviUPO position 158 (WT T158) / variant A158** *(alignment row index 222)*
# - **Residues across proteins:**
#   - **ET096 A171**, **CviUPO T158**, **CviUPO-F88L+T158A A158**, **DcaUPO F154**, **TE314 V183**, **OA167 P174**
# - **Substitution class:** **polarity + steric (small)**.
#   - **T (small, polar H-bond donor/acceptor)** → **A (small, nonpolar)**
# - **Mechanistic consequence (causal):**
#   - **T158 in CviUPO WT** can act as a **local H-bond “pin”** (directly or via structured water) that helps enforce **a single productive substrate orientation** near the reactive locus—consistent with the earlier **higher proximal polarity** and **mono-selective** phenotype.
#   - **T158A** removes that polar anchor, making the proximal region **chemically drier/more hydrophobic**, matching the summary (**↓prox polarity; ↑kd_weighted**). Mechanistically this should **weaken pose-locking**, increasing probability of **alternative binding geometries** and **second-oxidation competent reorientation**.
# - **Variant-specific contrast:**
#   - In the **double mutant**, **T158A** is the cleanest explanation for the summary’s “**slightly less polar clamp**” even if steric bulk fraction remains high.
#
# **Confidence:** high (directly mutated; polarity change aligns with global electrostatics shift).
#
# ---
#
# ### C. **CviUPO position 165 = K165 vs ET096 A178 / DcaUPO C161 / TE314 V190 / OA167 A181** *(alignment row index 229)*
# - **Residues across proteins:**
#   - **ET096 A178**, **CviUPO K165**, **CviUPO-F88L+T158A K165**, **DcaUPO C161**, **TE314 V190**, **OA167 A181**
# - **Substitution class:** strongly **electrostatic** (neutral ↔ positively charged) + polarity.
#   - **K (positively charged)** vs **A/V/C (neutral)**
# - **Mechanistic consequence (causal):**
#   - **CviUPO’s K165** is a plausible *electrostatic organizer* in an otherwise hydrophobic pocket: it can **stabilize polar ingress/egress waters**, influence **H2O2 positioning**, and/or **stabilize developing negative character** in transition states or radical intermediates. This directly supports the earlier observation that CviUPO has **more polar/partially charged proximal + notably polar distal** environment and is **ABTS-high (peroxidative competence)**.
#   - Enzymes with **neutral residues here (ET096/OA167/TE314)** lack this local cationic feature, consistent with their summaries emphasizing **uncharged proximal sets** and weaker electrostatic steering (ET096 especially).
# - **Variant-specific contrast:**
#   - **CviUPO WT vs double mutant:** K165 is unchanged, so the variant’s reduced polarity is **not** due to loss of charge here; instead, it supports the idea that **T158A/F88L** drive the “de-polarized clamp” while **K165 preserves some electrostatic capability**.
#
# **Confidence:** high as an electrostatic differentiator across homologs; moderate for direct catalytic effect (distance-dependent, but it is within the filtered <6 Å-in-some-structure set).
#
# ---
#
# ### D. **Position ~60: ET096 A77 vs CviUPO T60 vs DcaUPO D58 vs TE314 T80 vs OA167 A76** *(alignment row index 103)*
# - **Residues across proteins:**
#   - **ET096 A77**, **CviUPO T60**, **CviUPO-F88L+T158A T60**, **DcaUPO D58**, **TE314 T80**, **OA167 A76**
# - **Substitution class:** **electrostatic/polarity** (Asp vs Thr/Ala).
#   - **D (negatively charged)** vs **T (polar)** vs **A (nonpolar)**
# - **Mechanistic consequence (causal):**
#   - **DcaUPO D58** provides a **fixed negative charge** near the pocket that can (i) **shape substrate approach/orientation** via electrostatic steering and (ii) help explain why DcaUPO can be **peroxidative-capable** despite a “dry” proximal pocket: the summary notes **distal region most charged**; D58 could be part of that electrostatic network or a local contributor to ET competence.
#   - **ET096 A77** removes this steering element, consistent with ET096’s **essentially uncharged proximal electrostatics** and “generalist/permissive” behavior (more reorientation → more di-oxidation).
#   - **CviUPO/TE314 Thr** gives **weaker, directional H-bonding** (pose bias without full ionic steering), consistent with CviUPO’s “polar clamp” concept.
# - **Variant-specific contrast:**
#   - No change between **CviUPO WT and variant** at this position; thus it is a **cross-homolog driver**, not a variant driver.
#
# **Confidence:** moderate-high (clear charge swap; fits electrostatics phenotypes).
#
# ---
#
# ### E. **Position ~64: ET096 A80 vs CviUPO L64 vs DcaUPO F62 vs TE314 P84 vs OA167 L80** *(alignment row index 107)*
# - **Residues across proteins:**
#   - **ET096 A80**, **CviUPO L64**, **CviUPO-F88L+T158A L64**, **DcaUPO F62**, **TE314 P84**, **OA167 L80**
# - **Substitution class:** strongly **steric** (small ↔ bulky; aromatic vs aliphatic; conformational constraint via Pro).
# - **Mechanistic consequence (causal):**
#   - **ET096 A80 (small)** supports the summary’s **“small-residue rich, soft steric definition”** proximal pocket → easier **multiple binding geometries** and **re-binding/reorientation**, consistent with **low Mono:Di and high Di-Ox**.
#   - **DcaUPO F62 (bulky aromatic)** and **CviUPO/OA167 Leu** create a **harder wall** that should **reduce pose entropy** and increase probability of a single productive alignment (mono-selective tendency in CviUPO/DcaUPO).
#   - **TE314 P84** can reshape local backbone and pocket contour; this matches TE314’s “balanced” phenotype—**not extremely clamping**, but still structured.
# - **Variant-specific contrast:**
#   - Unchanged in CviUPO WT vs variant; again a **homolog-level steric driver**.
#
# **Confidence:** high for steric role (A vs F/L/P is a large cavity-shape change).
#
# ---
#
# ### F. **Position ~161: ET096 L174 vs CviUPO G161 vs DcaUPO G157 vs TE314 G186 vs OA167 F177** *(alignment row index 225)*
# - **Residues across proteins:**
#   - **ET096 L174**, **CviUPO G161**, **CviUPO-F88L+T158A G161**, **DcaUPO G157**, **TE314 G186**, **OA167 F177**
# - **Substitution class:** **steric gating** (Gly ↔ Leu/Phe).
# - **Mechanistic consequence (causal):**
#   - **Gly at this position (CviUPO/DcaUPO/TE314)** likely creates a **local notch/hinge-like openness** that can permit subtle substrate repositioning *without* adding bulk—useful for tight pockets that still need access.
#   - **ET096 L174** adds bulk relative to Gly, but ET096’s overall phenotype is still permissive because other positions (e.g., **A80**) keep the pocket “soft”; L174 may instead act as a **hydrophobic contact** rather than a clamp.
#   - **OA167 F177** is a strong bulky/aromatic plug that can increase binding/throughput on hydrophobes (fits OA167 “hydrophobic throughput”), but may also **promote multiple productive poses** if the cavity is large enough elsewhere (consistent with OA167 di-oxidation accessibility).
# - **Variant-specific contrast:** none within CviUPO family.
#
# **Confidence:** moderate (effect depends on exact geometry; but Gly↔Phe is typically impactful).
#
# ---
#
# ## 2) Ranked residue list (mechanistic importance)
#
# ### High-confidence mechanistic driver residues
# 1. **CviUPO F88 → L88 (variant)**: removes aromatic wall/π-clamp → directly explains “opened/de-aromatized, less polar clamp” behavior.
# 2. **CviUPO T158 → A158 (variant)**: removes a polar anchor → directly drives reduced proximal polarity/pose-locking.
# 3. **CviUPO K165 (vs neutral in others)**: key **electrostatic differentiator** supporting CviUPO’s more organized polar/charged environment and peroxidative competence.
# 4. **ET096 A80 (vs L/F/P)**: major **steric softening** consistent with ET096 permissiveness and over-oxidation tendency.
#
# ### Secondary modulators
# - **DcaUPO D58 (vs T/A)**: introduces negative charge; likely tunes access-channel/pocket electrostatics and orientation.
# - **Position ~161 (G vs L/F)**: local gating/packing modulator affecting pose entropy and reorientation pathways.
#
# ### Likely neutral/background (within this filtered set)
# - **Position ~74 (ET096 V74 / CviUPO L57 / DcaUPO L55 / TE314 L77 / OA167 T73)**: mostly conservative hydrophobe↔hydrophobe (except OA167 T); likely minor unless it directly contacts the substrate in a given pose.
# - **Position ~159 (mostly S/T/G)** and **~160 (A/Y/L)** in this table: changes are real but appear more distal in the provided distances for several proteins; likely context-dependent rather than primary phenotype drivers.
#
# If you want, I can reformat the above into a compact “mutation hypothesis sheet” per enzyme (what to mutate to push ET096 toward CviUPO-like mono-selectivity, or vice versa), using only positions present in this alignment.
# PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_llm_analysis.md')

# %% [markdown]
# ## Save Thread Update
# Run this final cell to append run metadata and prompt context to `chats/<llm_process_tag>_<thread_id>.json`.

# %%
persist_thread_update(
    root_key=root_key,
    thread_id=thread_id,
    user_inputs=user_inputs,
    input_paths=input_paths,
    selected_positions=selected_positions,
    reaction_df=reaction_df,
    out_interp=out_interp,
    out_patterns=out_patterns,
    llm_analysis_path=out_llm,
    llm_analysis_text=llm_analysis,
    llm_model=str(user_inputs.get("llm_model", "")),
)
# Out:
# '2026-02-12T15:28:24.119104+00:00'
