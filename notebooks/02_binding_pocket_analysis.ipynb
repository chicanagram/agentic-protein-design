# %% [markdown]
# # 02 - Binding Pocket Analysis
#
# Notebook UI for UPO homolog pocket analysis using an LLM with binding, alignment, and optional reaction inputs.

# %% [markdown]
# ## Python Path Setup
# Ensure project-root imports work whether Jupyter starts from repo root or `notebooks/`.

# %%
from pathlib import Path
import os
import sys

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %% [markdown]
# ## Imports
# Load helper functions for table loading, LLM analysis, output export, and thread persistence.

# %%
import importlib
import notebook_helpers.nb_02_binding_pocket_analysis as bp
bp = importlib.reload(bp)
from local_api_keys import OPENAI_API_KEY

analyze_pocket_profiles = bp.analyze_pocket_profiles
default_user_inputs = bp.default_user_inputs
build_prompt_with_context = bp.build_prompt_with_context
generate_llm_pocket_analysis = bp.generate_llm_pocket_analysis
init_thread = bp.init_thread
load_input_tables = bp.load_input_tables
persist_thread_update = bp.persist_thread_update
save_binding_outputs = bp.save_binding_outputs
save_llm_analysis = bp.save_llm_analysis
setup_data_root = bp.setup_data_root

# %% [markdown]
# ## API Key Setup
# Load the OpenAI key from `local_api_keys.py` into environment variables for LLM calls.

# %%
if OPENAI_API_KEY and OPENAI_API_KEY != "REPLACE_WITH_YOUR_OPENAI_API_KEY":
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

"OPENAI_API_KEY" in os.environ
# Out:
# True

# %% [markdown]
# ## User Inputs
# Edit all run parameters here (single place): dataset root, thread selection, analysis options, model, and input paths.

# %%
root_key = "PIPS2"
existing_thread_id = None

user_inputs = {
    "selected_positions": [100, 103, 104, 107, 141, 222],
    "focus_question": (
        "Identify per-protein structural interpretations and cross-homolog patterns "
        "that could explain activity/property differences."
    ),
    "reaction_data_description": (
        "- Veratryl alcohol: peroxygenative\n"
        "- Naphthalene: peroxygenative\n"
        "- NBD: peroxygenative\n"
        "- ABTS: peroxidative\n"
        "- S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased\n"
        "Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance."
    ),
    "use_reaction_data": True,
    "llm_model": "gpt-5.2",
    "llm_temperature": 0.2,
    "llm_max_rows_per_table": 300,
}

input_paths = {
    # Paths are relative to the data root from variables.address_dict[root_key].
    "binding_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv",
    "alignment_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv",
    "reaction_data_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv",
}

# Optional: reset analysis options from helper defaults
# user_inputs = default_user_inputs()

# %% [markdown]
# ## Setup Runtime Context
# Initialize data directories and active chat thread from the values above.

# %%
data_root, resolved_dirs = setup_data_root(root_key)
thread, threads_preview = init_thread(root_key, existing_thread_id)
thread_id = thread["thread_id"]
data_root, thread_id
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data'),
#  '59353c876ab140688b1c239a15aac24e')

# %% [markdown]
# ## Load Input Tables
# Load descriptor and alignment tables, and optional reaction data, from `input_paths`.

# %%
def resolve_input_path(path_value: str) -> Path:
    p = Path(path_value).expanduser()
    if p.is_absolute():
        return p.resolve()
    return (data_root / p).resolve()

binding_csv = resolve_input_path(input_paths["binding_csv"])
alignment_csv = resolve_input_path(input_paths["alignment_csv"])
reaction_data_csv = None
if user_inputs.get("use_reaction_data", False) and input_paths.get("reaction_data_csv", "").strip():
    reaction_data_csv = resolve_input_path(input_paths["reaction_data_csv"])

pocket, ali, reaction_df = load_input_tables(binding_csv, alignment_csv, reaction_data_csv)
binding_csv, alignment_csv, reaction_data_csv, pocket.head(3), (None if reaction_df is None else reaction_df.head(3))
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv'),
#     Unnamed: 0                    struct_name  num_pocket_res_ali  \
#  0           0                ET096_S82_glide                  38
#  1           1               CviUPO_S82_glide                  39
#  2           2  CviUPO-F88L+T158A_S82_chai1_0                  33
#
#     num_pocket_res<6  reactive_center_distance  \
#  0                12                     7.095
#  1                13                     7.720
#  2                10                     5.827
#
#     median_dist_res_to_ligand_reactive_center  median_min_dist_res_to_ligand  \
#  0                                      7.921                          4.330
#  1                                      6.683                          3.575
#  2                                      6.922                          4.155
#
#     mean_min_dist_to_centroid  mean_dist_to_centroid  \
#  0                      8.570                 10.247
#  1                      8.079                  9.906
#  2                      7.691                  9.631
#
#     mean_dist_backbone_to_centroid  ...  small_residue_frac  \
#  0                          10.067  ...               0.368
#  1                           9.817  ...               0.179
#  2                           9.484  ...               0.182
#
#     small_residue_frac_weighted  bulky_residue_frac  \
#  0                        0.386               0.368
#  1                        0.193               0.410
#  2                        0.223               0.455
#
#     bulky_residue_frac_weighted  kd_mean  kd_weighted  hw_mean  hw_weighted  \
#  0                        0.351    0.876        0.967   -0.466       -0.464
#  1                        0.410    0.410        0.387   -0.546       -0.475
#  2                        0.443    0.803        0.730   -0.658       -0.533
#
#     charged_fraction  polar_fraction
#  0             0.132           0.368
#  1             0.128           0.513
#  2             0.121           0.485
#
#  [3 rows x 23 columns],
#    UPO Homologs  Veratryl alcohol (peroxygenation)  \
#  0        ET096                              0.597
#  1       CviUPO                              0.333
#  2       DcaUPO                              1.558
#
#     Naphthalene (peroxygenation)  NBD (peroxygenation)  ABTS (peroxidation)  \
#  0                         0.127                 0.053                0.146
#  1                         0.168                 0.169                3.939
#  2                         0.136                 1.242                2.700
#
#     S82 Mono-Ox %yield  S82 Di-Ox % Yield  S82 Total % Yield  S82 Mono:Di Ratio
#  0                 8.4               32.7               41.1                0.3
#  1                14.8                8.9               23.7                1.7
#  2                10.0                6.2               16.2                1.6  )

# %% [markdown]
# ## Structured Exports
# Generate heuristic comparative tables and export CSVs to `processed/`.

# %%
selected_positions = user_inputs["selected_positions"]
interp_df, pattern_summary = analyze_pocket_profiles(pocket, ali, selected_positions)
out_interp, out_patterns = save_binding_outputs(interp_df, pattern_summary, resolved_dirs["processed"])
out_interp, out_patterns
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_interpretations.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_pattern_summary.csv'))

# %% [markdown]
# ## LLM Pocket Analysis
# Query the LLM client with the full prompt and input tables, then save markdown output.
#
# Prerequisite: set `OPENAI_API_KEY` in `local_api_keys.py`.

# %%
prompt_text = build_prompt_with_context(reaction_df, user_inputs)
print("=== Prompt Sent To LLM ===")
print(prompt_text)
print("\n=== LLM Output ===")
llm_analysis = generate_llm_pocket_analysis(pocket, ali, reaction_df, user_inputs)
print(llm_analysis)
out_llm = save_llm_analysis(llm_analysis, resolved_dirs["processed"])
out_llm
# Out:
# === Prompt Sent To LLM ===
#
# Analyse the uploaded inputs for a set of proteins to interpret how binding-pocket structure relates to catalytic activity and selectivity.
#
# INPUTS
# - binding_pocket_table: table of extracted binding-pocket properties (per protein)
# - pocket_alignment_table: filtered residue alignment of pocket-proximal positions
# - reaction_data (optional): table or dict summarising enzyme activity on different substrates
#
# TASKS
# 1. For each protein, generate a concise **3–4 bullet summary** of its binding-pocket geometry and chemistry.
# 2. Interpret how these properties are likely to influence **catalytic activity and selectivity**, especially productive (e.g. peroxygenative) vs non-productive or competing (e.g. peroxidative) pathways.
# 3. If variants of the same protein are present, **explicitly contrast them** and explain how observed pocket differences could rationalise functional changes.
# 4. Briefly distil **cross-protein trends or clusters** (“pocket phenotypes”) that explain systematic behaviour differences across the panel.
# 5. Optionally integrate reaction_data to connect structural features to observed substrate-specific behaviour.
#
# POCKET FEATURES TO CONSIDER
#
# Pocket size / alignment coverage
# - num_pocket_res_ali: number of aligned positions within a distance cutoff of any docked ligand
# - num_pocket_res_lt6: number of residues close to the ligand in each structure
#
# Ligand-dependent geometry
# - reactive_center_distance: distance between ligand reactive atom and catalytic center
# - median_dist_res_to_ligand_reactive_center: median distance between pocket residue centroids and ligand reactive atom
# - median_min_dist_res_to_ligand: median minimum distance between each pocket residue and any ligand heavy atom
#
# Ligand-independent pocket geometry
# - mean_dist_backbone_to_centroid
# - mean_dist_to_centroid
# - mean_min_dist_to_centroid
#
# Side-chain sterics (aligned pocket residues)
# - mean_volume, weighted_mean_volume, volume_variance
# - small_residue_frac, small_residue_frac_weighted
# - bulky_residue_frac, bulky_residue_frac_weighted
#
# Pocket polarity / electrostatics
# - kd_mean, kd_weighted (hydrophobicity; higher = more hydrophobic)
# - hw_mean, hw_weighted (polarity/exposure; more negative = less polar / less exposed)
# - charged_fraction, polar_fraction
#
# ALIGNMENT CONTEXT
# The residue alignment has been filtered to include only positions that:
# - show sequence variability (≥1 amino-acid type or gap), and
# - are within the distance cutoff to the ligand in at least one structure.
# Use this information to reason about which **variable positions directly shape the binding pocket** versus those that are peripheral.
#
# REACTION CONTEXT (OPTIONAL)
# - Veratryl alcohol: peroxygenative
# - Naphthalene: peroxygenative
# - NBD: peroxygenative
# - ABTS: peroxidative
# - S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased
# Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance.
#
# OUTPUT STYLE
# - Use clear, human-interpretable language.
# - Emphasise geometric and chemical intuition over raw numbers.
# - Keep summaries compact, comparative, and mechanistically grounded.
#
#
# REACTION_DATA_STATUS: provided. Rows=5, Columns=['UPO Homologs', 'Veratryl alcohol (peroxygenation)', 'Naphthalene (peroxygenation)', 'NBD (peroxygenation)', 'ABTS (peroxidation)', 'S82 Mono-Ox %yield', 'S82 Di-Ox % Yield', 'S82 Total % Yield', 'S82 Mono:Di Ratio']
#
# === LLM Output ===
# ## Per-protein pocket summaries (geometry/chemistry → expected functional bias)
#
# ### ET096 (ET096_S82_glide)
# - **More open/less “contact-rich” near the ligand**: fewer residues within 6 Å (12) and the **largest median ligand contact distance** (median min dist ~4.33 Å) → weaker shape complementarity / looser pose control.
# - **Reactive placement is relatively poor**: **reactive-center distance ~7.10 Å** (longest except CviUPO) → less frequent productive near-oxo geometries for HAT/O-insertion.
# - **Hydrophobic but not extremely** (kd ~0.88–0.97) with **moderate polarity** (polar frac ~0.37) and **moderate charged content** (~0.13) → can bind aromatics, but without strong polar anchoring.
# - **Sterics are “balanced”**: unusually high **small-residue fraction (~0.37)** *and* similar bulky fraction (~0.37) plus high volume variance → heterogeneous pocket that may allow multiple, competing binding modes.
#
# **Activity/selectivity interpretation (using reaction_data):**
# - ET096 shows **low ABTS (0.146)** but **high S82 di-oxidation (32.7%)** and low Mono:Di (0.3). A plausible structural rationale is **loose positioning** (long reactive distance + fewer tight contacts) that allows S82 to adopt orientations favoring **sequential/over-oxidation** once the first oxidation occurs (i.e., less control over “stop-at-mono”).
# - The same looseness can reduce classic peroxidative turnover on ABTS (which often benefits from well-positioned surface/entry-site ET geometries), while still allowing S82 to be processed extensively via repeated binding/oxidation events.
#
# ---
#
# ### CviUPO (CviUPO_S82_glide)
# - **Most “contact-rich” pocket**: highest residues within 6 Å (13) and **tightest ligand proximity** (median min dist ~3.58 Å) → stronger pose definition.
# - **Reactive placement still not ideal by distance**: reactive-center distance ~7.72 Å (largest), but **median residue-to-reactive-center is smallest (~6.68 Å)** → residues crowd the reactive region even if the docked reactive atom sits farther from the metal/oxo.
# - **More polar/less hydrophobic overall**: kd ~0.39–0.41 with **high polar fraction (~0.51)** → better capacity for polar anchoring / H-bond networks that can “lock” substrate orientation.
# - **Bulky-leaning sterics**: bulky fraction ~0.41 with low small fraction (~0.18) → narrower, more sculpted cavity.
#
# **Activity/selectivity interpretation:**
# - Reaction data show **very high ABTS (3.939)** and **Mono:Di = 1.7** (mono favored). This matches a pocket that is **more polar and tightly shaping**: it can support **electron-transfer/peroxidative chemistry** (ABTS) and also **restrict S82** to fewer productive orientations, reducing over-oxidation (lower di-ox than ET096).
# - Despite the long reactive-center distance metric, the **tight contact shell** suggests that small shifts (induced fit / dynamics) could bring the reactive atom into range more often than the single docked snapshot implies.
#
# ---
#
# ### CviUPO-F88L+T158A (CviUPO-F88L+T158A_S82_chai1_0) — variant vs CviUPO
# - **More “open” / less covered pocket**: fewer aligned pocket residues (33 vs 39) and fewer within 6 Å (10 vs 13) → reduced geometric constraint.
# - **Improved reactive placement**: reactive-center distance drops to **~5.83 Å** (from 7.72 Å) → higher probability of productive near-oxo geometries for oxygen transfer.
# - **More hydrophobic than WT CviUPO**: kd rises to ~0.73–0.80 while remaining fairly polar (polar frac ~0.49) → shifts binding toward hydrophobic packing while keeping some anchoring.
# - **Local steric edits consistent with “repacking”**: F88L removes an aromatic wall; T158A removes a polar side chain and creates space—together likely **re-route/relax** the binding channel and allow deeper approach.
#
# **Functional expectation (no direct reaction_data row for the variant):**
# - The **shorter reactive-center distance** strongly predicts **enhanced peroxygenative competence** (more productive oxygen transfer) relative to WT CviUPO, potentially at the cost of **less strict pose control** (which could increase side reactions or broaden regioselectivity).
# - Given WT CviUPO’s strong ABTS/peroxidative signal, the variant’s **hydrophobization + deeper access** would be expected to **shift balance toward peroxygenation** on hydrophobic substrates (and possibly reduce ABTS preference if the ET-favorable polar environment is diminished).
#
# ---
#
# ### DcaUPO (DcaUPO_S82_glide)
# - **Most crowded near-ligand shell**: highest residues within 6 Å (15) → strong steric definition around the bound substrate.
# - **Best reactive placement among measured homologs**: reactive-center distance **~4.93 Å** → favorable for productive oxygen transfer.
# - **Hydrophobic pocket with higher charge content**: kd ~0.79–0.82 and **charged fraction ~0.20** (highest) → can support both hydrophobic packing and specific electrostatic steering.
# - **Bulky-biased sterics** (bulky ~0.40; small ~0.15) → tighter, more selective cavity.
#
# **Activity/selectivity interpretation:**
# - DcaUPO shows **high peroxygenation on veratryl alcohol (1.558) and NBD (1.242)** *and* high ABTS (2.7), plus **Mono:Di = 1.6**. Structurally, this is consistent with a pocket that both:
#   - places substrates **close to the reactive center** (peroxygenation competence), and
#   - provides **electrostatic/charged features** that can facilitate peroxidative ET chemistry (ABTS) without sacrificing oxygen transfer.
# - The tight shell + good reactive distance also rationalizes **mono-selectivity** on S82 (less over-oxidation than ET096), because constrained binding can enforce a dominant productive pose and/or hinder rebinding of the mono-oxidized product in an over-oxidation pose.
#
# ---
#
# ### TE314 (TE314_S82_chai1_0)
# - **Very hydrophobic and least exposed/polar**: highest kd (~1.43) and very negative hw (~-0.70) → strongly nonpolar pocket environment.
# - **Excellent reactive placement**: reactive-center distance **~4.08 Å** (best) → high intrinsic peroxygenation potential if substrate can access/orient.
# - **Moderate contact richness** (12 residues <6 Å) with **moderate steric bulk** (bulky ~0.37; small ~0.23) → not as tightly “caged” as DcaUPO.
# - **Low charged fraction (~0.11)** → fewer electrostatic steering elements.
#
# **Activity/selectivity interpretation (S82 only available):**
# - TE314 has **high total S82 yield (36.5%)** but **Mono:Di = 0.7** (di significant). A plausible explanation is: **deep hydrophobic pocket + very short reactive distance** promotes fast oxidation, but **lack of polar/charged anchoring** allows multiple binding modes and easy rebinding of partially oxidized intermediates → more over-oxidation than DcaUPO/CviUPO.
# - Expectation: strong activity on hydrophobic substrates, potentially broader/less controlled selectivity.
#
# ---
#
# ### OA167 (OA167_S82_swissdock_0)
# - **Hydrophobic, low-polarity pocket**: kd ~1.03 with hw ~-0.67; polar fraction ~0.40; low charged fraction (~0.11).
# - **Good ligand proximity**: median min dist ~3.60 Å (tight contacts), but **fewer residues within 6 Å (10)** → fewer “hard constraints” despite close packing where it does contact.
# - **Good reactive placement**: reactive-center distance **~4.55 Å** → peroxygenation-favorable geometry.
# - **Sterics moderately bulky** (bulky ~0.37; small ~0.26) → intermediate between TE314 and ET096.
#
# **Activity/selectivity interpretation (S82 only available):**
# - OA167 shows **highest S82 total yield (46.8%)** with **Mono:Di = 0.6** (di favored). This fits a phenotype of **hydrophobic + reactive-center-proximal** pocket that drives oxidation efficiently but, without strong polar “pose locks,” allows **multiple productive orientations** and **over-oxidation**.
#
# ---
#
# ## Explicit contrasts among variants/homologs
#
# ### CviUPO vs CviUPO-F88L+T158A (most direct structural “cause → effect” signal)
# - **Reactive-center distance improves dramatically** (7.72 → 5.83 Å): predicts a **shift toward peroxygenative productivity** (more frequent near-oxo approach).
# - **Pocket constraint decreases** (contacts and aligned coverage drop): predicts **broader substrate tolerance** but potentially **less selectivity control** (more competing orientations).
# - **Hydrophobicity increases**: likely improves binding/turnover for hydrophobic substrates and may reduce the strong ABTS/peroxidative bias seen in WT CviUPO.
#
# ### ET096 vs (DcaUPO / TE314 / OA167)
# - ET096 is the outlier with **long reactive distance** and **looser ligand proximity**, matching its **low mono-selectivity (Mono:Di 0.3)** and tendency toward extensive di-oxidation.
# - DcaUPO/TE314/OA167 all have **short reactive distances (~4–5 Å)** and correspondingly **higher S82 total yields**, consistent with more productive oxygen transfer geometries.
#
# ### DcaUPO vs TE314/OA167 (why DcaUPO is more mono-selective)
# - DcaUPO combines **short reactive distance** *and* **high contact richness (15 residues <6 Å)** plus **higher charged fraction (0.20)** → better geometric/electrostatic steering, aligning with **higher Mono:Di (1.6)**.
# - TE314/OA167 are hydrophobic and reactive-close but **less electrostatically structured**, aligning with **lower Mono:Di (0.7 / 0.6)** and more over-oxidation.
#
# ---
#
# ## Cross-protein “pocket phenotypes” (clusters) explaining systematic behavior
#
# ### Phenotype 1: **Reactive-close, hydrophobic, weakly polar-anchored** (TE314, OA167)
# - Signature: **reactive-center distance ~4–4.6 Å**, **high kd**, **low charged fraction**.
# - Behavior: **high overall oxidation throughput** on hydrophobic substrates, but **more over-oxidation / mixed selectivity** (lower Mono:Di), consistent with multiple accessible poses and easy rebinding.
#
# ### Phenotype 2: **Reactive-close, contact-rich, electrostatically structured** (DcaUPO)
# - Signature: short reactive distance + **many residues within 6 Å** + **higher charged fraction**.
# - Behavior: strong peroxygenation capability **with better control** (higher mono selectivity), and can also support peroxidative activity (ABTS) via ET-friendly features.
#
# ### Phenotype 3: **Polar, tightly sculpted, peroxidation-leaning** (CviUPO WT)
# - Signature: **low kd (more polar)**, **tight ligand proximity**, bulky-biased sterics.
# - Behavior: strong **ABTS/peroxidative** activity and improved mono selectivity; peroxygenation depends sensitively on whether dynamics can overcome the longer docked reactive distance.
#
# ### Phenotype 4: **Loose/heterogeneous pocket with poor reactive placement** (ET096)
# - Signature: **long reactive distance**, fewer close contacts, high small-residue fraction and high variance.
# - Behavior: weaker control and poorer productive placement → **more non-ideal outcomes** (here: strong di-oxidation dominance on S82, low ABTS).
#
# ---
#
# ## Variable pocket positions that likely matter (from the filtered alignment)
# Across homologs, several variable positions sit **very close to ligand/reactive center in at least one enzyme**, so they are plausible “hotspots” controlling phenotype:
# - **~88 position (CviUPO numbering)**: WT **F88** vs variant **L88** (and other homologs often L/I). Aromatic→aliphatic change can **remove π-stacking/steric wall**, enabling deeper approach (consistent with the variant’s shorter reactive distance).
# - **~158 position**: WT **T158** vs variant **A158**; other homologs vary widely (T/F/V/P). This position appears close in some structures (min distances ~3–4 Å in several entries), so it likely acts as a **gate/ledge** controlling substrate depth and tilt—key for Mono vs Di outcomes.
# - **~160–161 region (Y/L/G/F variability)**: toggles between **bulky aromatic (Y/F)** and **small (G)**, which can strongly reshape the channel cross-section and enforce/relax a dominant pose.
# - **Early pocket positions (~57–64 region)**: L/T/I/F/P variability near the ligand in some homologs suggests a **rim/entry shaping role**, influencing which substrates can enter and whether ABTS-like peroxidative binding is favored.
#
# If you want, I can (i) map these variable positions into “likely gate vs floor vs wall” roles per enzyme using the per-residue distance columns, and (ii) propose a minimal mutation set to shift any enzyme toward a desired phenotype (e.g., increase Mono:Di without losing total yield).
# PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_llm_analysis.md')

# %% [markdown]
# ## Save Thread Update
# Run this final cell to append run metadata and prompt context to `chats/<thread_id>.json`.

# %%
persist_thread_update(
    root_key=root_key,
    thread_id=thread_id,
    user_inputs=user_inputs,
    input_paths=input_paths,
    selected_positions=selected_positions,
    reaction_df=reaction_df,
    out_interp=out_interp,
    out_patterns=out_patterns,
    llm_analysis_path=out_llm,
    llm_analysis_text=llm_analysis,
    llm_model=str(user_inputs.get("llm_model", "")),
)
# Out:
# '2026-02-11T05:45:46.094909+00:00'
