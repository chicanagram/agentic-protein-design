# %% [markdown]
# # 01 - Literature Review
#
# Notebook UI for retrieval-backed enzyme literature survey and LLM-generated engineering-focused synthesis.

# %% [markdown]
# ## Python Path Setup
# Ensure project-root imports work whether Jupyter starts from repo root or `notebooks/`.

# %%
from pathlib import Path
import os
import sys

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
src_root = repo_root / "src"
if src_root.exists() and str(src_root) not in sys.path:
    sys.path.insert(0, str(src_root))

# %% [markdown]
# ## Imports
# Load helper functions for setup, retrieval, prompt construction, LLM synthesis, and thread persistence.

# %%
import importlib
import agentic_protein_design.steps.literature_review as lr
lr = importlib.reload(lr)
from project_config.local_api_keys import OPENAI_API_KEY

build_literature_agent_prompt = lr.build_literature_agent_prompt
default_user_inputs = lr.default_user_inputs
generate_literature_llm_review = lr.generate_literature_llm_review
init_thread = lr.init_thread
persist_thread_update = lr.persist_thread_update
run_literature_pipeline = lr.run_literature_pipeline
save_literature_llm_review = lr.save_literature_llm_review
save_literature_outputs = lr.save_literature_outputs
setup_data_root = lr.setup_data_root

# %% [markdown]
# ## API Key Setup
# Load the OpenAI key from `project_config/local_api_keys.py` into environment variables for LLM calls.

# %%
if OPENAI_API_KEY and OPENAI_API_KEY != "REPLACE_WITH_YOUR_OPENAI_API_KEY":
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

"OPENAI_API_KEY" in os.environ
# Out:
# True

# %% [markdown]
# ## User Inputs
# Edit all run parameters here (single place): root/thread selection, literature prompt placeholders, retrieval settings, model, and root-relative input paths.

# %%
root_key = "PIPS2"
existing_thread_id = None

user_inputs = {
    "enzyme_family": "unspecific peroxygenases (UPOs)",
    "seed_sequences": ["CviUPO"],
    "reactions_of_interest": "peroxygenation of aromatics",
    "substrates_of_interest": ["Veratryl alcohol", "Naphthalene", "NBD", "ABTS"],
    "application_context": "biocatalysis, pharmaceutical synthesis, green chemistry",
    "constraints": ["stability", "solvent tolerance", "H2O2 tolerance", "expression host"],
    "keywords": ["peroxygenation"],
    "search_sources": [
        "UniProt",
        "InterPro",
        "PDB",
        "AlphaFold DB",
        "PubMed",
        "EuropePMC",
        "OpenAlex",
        "WebSearch",
    ],
    "literature_targets": ["bioRxiv", "Nature", "ScienceDirect", "PNAS", "ACS", "Wiley", "ChemRxiv"],
    "evidence_focus": [
        "protein_annotations",
        "structure",
        "reaction_mechanism",
        "historical_mutations",
    ],
    "max_results_per_source": 20,
    "fetch_open_access_fulltext": True,
    "fulltext_max_chars": 6000,
    "llm_model": "gpt-5.2",
    "llm_temperature": 0.2,
    "llm_max_rows_per_table": 250,
    "enable_relaxed_fallback": True,
    "min_quality_score_for_llm_context": 0.35,
}

input_paths = {
    # Paths are relative to the data root from project_config.variables.address_dict[root_key].
    "seed_sequences_file": "",
    "constraints_file": "",
}

# Optional: reset all fields from helper defaults
# user_inputs = default_user_inputs()

# %% [markdown]
# ## Setup Runtime Context
# Initialize data directories and active chat thread from the values above.

# %%
data_root, resolved_dirs = setup_data_root(root_key)
thread, threads_preview = init_thread(root_key, existing_thread_id)
thread_id = thread["thread_id"]
data_root, thread_id
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data'),
#  'a5f89fce81a0426781f7bcc1e4016bbf')

# %% [markdown]
# ## Optional Local Input Files
# Load optional root-relative files for seed sequences and constraints to enrich the prompt placeholders.

# %%
def resolve_input_path(path_value: str) -> Path:
    p = Path(path_value).expanduser()
    if p.is_absolute():
        return p.resolve()
    return (data_root / p).resolve()

seed_file_val = input_paths.get("seed_sequences_file", "").strip()
if seed_file_val:
    seed_file = resolve_input_path(seed_file_val)
    if seed_file.exists():
        lines = [l.strip() for l in seed_file.read_text(encoding="utf-8").splitlines() if l.strip()]
        if lines:
            user_inputs["seed_sequences"] = lines

constraints_file_val = input_paths.get("constraints_file", "").strip()
if constraints_file_val:
    constraints_file = resolve_input_path(constraints_file_val)
    if constraints_file.exists():
        clines = [l.strip() for l in constraints_file.read_text(encoding="utf-8").splitlines() if l.strip()]
        if clines:
            user_inputs["constraints"] = clines

# %% [markdown]
# ## Retrieve And Export
# Run retrieval against selected protein/literature databases plus optional general web search, then export CSV outputs.

# %%
outputs = run_literature_pipeline(user_inputs)
out_paths = save_literature_outputs(outputs, resolved_dirs["processed"])
outputs["source_report"], outputs.get("source_debug"), outputs.get("literature_hits", []).head(10) if hasattr(outputs.get("literature_hits", None), "head") else outputs.get("literature_hits"), out_paths
# Out:
# (                  metric  value
#  0  total_literature_hits      4
#  1           biorxiv_hits      0
#  2            nature_hits      0
#  3     sciencedirect_hits      0
#  4       open_access_hits      3
#  5      high_quality_hits      4
#  6    medium_quality_hits      0
#  7       low_quality_hits      0,
#            source query_mode  \
#  0        UniProt    primary
#  1       InterPro    primary
#  2            PDB    primary
#  3   AlphaFold DB    primary
#  4         PubMed    primary
#  5      EuropePMC    primary
#  6       OpenAlex    primary
#  7      WebSearch    primary
#  8        UniProt    relaxed
#  9       InterPro    relaxed
#  10           PDB    relaxed
#  11  AlphaFold DB    relaxed
#  12        PubMed    relaxed
#  13     EuropePMC    relaxed
#  14      OpenAlex    relaxed
#  15     WebSearch    relaxed
#
#                                                  query  rows  \
#  0   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  1   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  2   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  3   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  4   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  5   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  6   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  7   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  8   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  9   unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  10  unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  11  unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  12  unspecific peroxygenases (UPOs) CviUPO peroxyg...     3
#  13  unspecific peroxygenases (UPOs) CviUPO peroxyg...     1
#  14  unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#  15  unspecific peroxygenases (UPOs) CviUPO peroxyg...     0
#
#                                                  error
#  0
#  1   JSONDecodeError: Expecting value: line 1 colum...
#  2   HTTPError: 400 Client Error: Bad Request for u...
#  3   HTTPError: 422 Client Error: unknown for url: ...
#  4
#  5
#  6   HTTPError: 400 Client Error: Bad Request for u...
#  7
#  8
#  9   ReadTimeout: HTTPSConnectionPool(host='www.ebi...
#  10  HTTPError: 400 Client Error: Bad Request for u...
#  11  HTTPError: 422 Client Error: unknown for url: ...
#  12
#  13
#  14  HTTPError: 400 Client Error: Bad Request for u...
#  15                                                     ,
#        source        id                                              title  \
#  0     PubMed  39181196  Exploiting UPO versatility to transform rutin ...
#  1     PubMed  35453429  Novel Fatty Acid Chain-Shortening by Fungal Pe...
#  2     PubMed  31820805  UPObase: an online database of unspecific pero...
#  3  EuropePMC  35624779  Engineering <i>Collariella virescens</i> Perox...
#
#                                               journal  year  \
#  0                                  New biotechnology  2024
#  1                  Antioxidants (Basel, Switzerland)  2022
#  2  Database : the journal of biological databases...  2019
#  3                                                     2022
#
#                                              abstract  is_open_access  \
#  0  The discovery of unspecific peroxygenases (UPO...           False
#  1  Unspecific peroxygenases (UPOs), the extracell...            True
#  2  There are many unspecific peroxygenases (UPOs)...            True
#  3  Vegetable oils are valuable renewable resource...            True
#
#                                          fulltext_url  \
#  0
#  1  https://pmc.ncbi.nlm.nih.gov/articles/PMC9025384/
#  2  https://pmc.ncbi.nlm.nih.gov/articles/PMC6902001/
#  3          https://europepmc.org/articles/PMC9137900
#
#                                           url       pmcid  \
#  0  https://pubmed.ncbi.nlm.nih.gov/39181196/
#  1  https://pubmed.ncbi.nlm.nih.gov/35453429/  PMC9025384
#  2  https://pubmed.ncbi.nlm.nih.gov/31820805/  PMC6902001
#  3     https://doi.org/10.3390/antiox11050915  PMC9137900
#
#                                            host_venue  \
#  0                                  New biotechnology
#  1                  Antioxidants (Basel, Switzerland)
#  2  Database : the journal of biological databases...
#  3
#
#                                      fulltext_excerpt  is_biorxiv  is_nature  \
#  0                                                          False      False
#  1  pmc Antioxidants (Basel) Antioxidants (Basel) ...       False      False
#  2  Database (Oxford) Database (Oxford) 973 databa...       False      False
#  3  2840 antiox Antioxidants Antioxidants (Basel) ...       False      False
#
#     is_sciencedirect target_matches  quality_score quality_tier
#  0             False                          1.00         high
#  1             False                          1.00         high
#  2             False                          1.00         high
#  3             False                          0.95         high  ,
#  {'literature_summary': PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/literature_summary.csv'),
#   'literature_hits': PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/literature_hits.csv'),
#   'protein_database_hits': PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/protein_database_hits.csv'),
#   'literature_source_report': PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/literature_source_report.csv'),
#   'literature_source_debug.csv': PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/literature_source_debug.csv'),
#   'web_search_hits.csv': PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/web_search_hits.csv')})

# %% [markdown]
# ## LLM Literature Synthesis
# Print the full prompt, call the LLM with retrieval context, and save the generated review.

# %%
prompt_text = build_literature_agent_prompt(user_inputs)
print("=== Prompt Sent To LLM ===")
print(prompt_text)
print("\n=== LLM Output ===")
llm_review = generate_literature_llm_review(outputs, user_inputs)
print(llm_review)
out_llm = save_literature_llm_review(llm_review, resolved_dirs["processed"])
out_llm
# Out:
# === Prompt Sent To LLM ===
#
# You are an AI research agent supporting an enzyme engineering project.
# Your role is to conduct a structured, technically rigorous literature review and generate a concise but insight-dense summary to guide experimental design.
#
# INPUTS (provided dynamically)
# - enzyme_family: unspecific peroxygenases (UPOs)
# - seed_sequences (optional): CviUPO
# - reactions_of_interest: peroxygenation of aromatics
# - substrates_of_interest (optional): Veratryl alcohol Naphthalene NBD ABTS
# - application_context (optional): biocatalysis, pharmaceutical synthesis, green chemistry
# - constraints (optional): stability solvent tolerance H2O2 tolerance expression host
#
# OBJECTIVE
# Gather and synthesize current knowledge on:
# 1. Enzyme class structure and fold
# 2. Reaction mechanism (including intermediates, catalytic residues, cofactors)
# 3. Substrate scope and known selectivity trends
# 4. Cofactor requirements and catalytic cycle
# 5. Known engineering efforts (mutagenesis, directed evolution, ML-guided design)
# 6. Stability, expression, and formulation constraints
# 7. Gaps in knowledge and opportunities for engineering
#
# SOURCES TO CONSULT
# - Protein databases: UniProt, PDB, AlphaFold DB, InterPro, Pfam
# - Literature databases: PubMed, Nature, PNAS, Science, ScienceDirect, ACS, Wiley, bioRxiv, ChemRxiv
# - Reviews and meta-analyses when available
# - Structural studies (crystal structures, cryo-EM)
# - Mechanistic enzymology papers
# - Directed evolution and protein engineering studies
#
# INSTRUCTIONS FOR INFORMATION GATHERING
# - Prioritize peer-reviewed literature and high-impact reviews.
# - Distinguish between experimentally validated findings and computational predictions.
# - Extract quantitative data when possible (kcat, KM, TTN, enantioselectivity, stability metrics, mutation effects).
# - Identify conserved catalytic residues and structural motifs.
# - Map engineering-relevant residues (active site, access channel, gating residues, stability hotspots).
# - Note contradictions or unresolved mechanistic questions.
#
# OUTPUT FORMAT
#
# 1. Executive Summary (<=10 bullet points)
#    - High-level takeaways most relevant to engineering strategy.
#
# 2. Structural Overview
#    - Fold classification
#    - Domain architecture
#    - Active site organization
#    - Access channels / substrate tunnels
#    - Cofactor binding
#
# 3. Reaction Mechanism
#    - Catalytic cycle steps
#    - Key intermediates
#    - Rate-limiting steps (if known)
#    - Competing pathways (e.g. peroxygenation vs peroxidation)
#    - Determinants of chemoselectivity / regioselectivity
#
# 4. Substrate Scope & Selectivity Trends
#    - Classes of substrates accepted
#    - Structural features tolerated
#    - Trends in polarity, size, electronics
#    - Known limitations
#
# 5. Engineering Landscape
#    - Mutations known to affect activity/selectivity
#    - Stability-enhancing mutations
#    - Expression improvements
#    - Channel reshaping strategies
#    - ML-guided or computational design efforts
#    - Reported performance gains (quantitative if available)
#
# 6. Practical Constraints
#    - Cofactor stability (e.g. H2O2 sensitivity)
#    - Uncoupling / inactivation pathways
#    - Expression hosts used
#    - Solvent/temperature/pH tolerance
#
# 7. Comparative Analysis (if multiple homologs provided)
#    - Structural or mechanistic differences
#    - Performance trade-offs
#    - Known phenotypic clusters
#
# 8. Engineering Opportunities
#    - Hypothesis-driven mutation targets
#    - Channel/gating positions
#    - Electrostatic tuning opportunities
#    - Stability engineering strategies
#    - Assay design suggestions
#
# 9. References
#    - Provide full citations (authors, year, journal)
#    - Include DOI or PubMed ID where available
#    - Clearly distinguish review vs primary research
#
# STYLE REQUIREMENTS
# - Write clearly and technically, suitable for a PhD-level enzyme engineering audience.
# - Emphasize mechanistic reasoning and structure-function relationships.
# - Avoid generic textbook explanations.
# - Highlight actionable insights for experimental design.
# - Be concise but information-dense.
#
# If seed_sequences are provided:
# - Identify closest homologs.
# - Summarize known structures and variants for those sequences.
# - Highlight residue positions frequently engineered.
#
# If reactions_of_interest are specified:
# - Focus mechanistic discussion on those reaction classes.
# - Distinguish between productive and competing pathways.
#
# The goal is not just to summarize literature, but to extract engineering-relevant insight that can guide rational or ML-assisted enzyme optimization.
#
#
# === LLM Output ===
# ## 1. Executive Summary (engineering-relevant takeaways)
# - **UPOs are secreted fungal heme‑thiolate enzymes (EC 1.11.2.1)** that perform **P450-like oxyfunctionalization** using only **H₂O₂** (no NAD(P)H/redox partners), but they also catalyze **peroxidative one‑electron oxidations** that can dominate with phenolics/dyes (ABTS) and cause **radical coupling/oligomerization**.
# - **Chemoselectivity (peroxygenation vs peroxidation)** is strongly **process-controlled** (H₂O₂ delivery, radical scavengers, cosolvent) and **structure-controlled** (access channel geometry and aromatic binding pose).
# - **Active-site “channel reshaping” is a validated engineering lever**: alanine scanning in the **heme access channel** of **rCviUPO** improved oxygenation outcomes; **F88A/T158A** is a proven “opening” mutation pair (validated for fatty-acid epoxidation; concept likely transferable to aromatic peroxygenation where sterics limit productive binding).
# - **Aromatic peroxygenation** typically proceeds via **Compound I (Fe(IV)=O porphyrin π‑cation radical)**; competing **one‑electron oxidation** generates substrate radicals (problematic for ABTS and polyphenols; can be harnessed for polymerization).
# - **H₂O₂ tolerance is a primary constraint**: excess peroxide drives **heme destruction/oxidative inactivation** and uncoupling; controlled in situ H₂O₂ generation or fed‑batch dosing is usually required for preparative reactions.
# - **Assay choice matters**: ABTS is excellent for activity readout but biases toward **peroxidase mode**; for aromatic peroxygenation engineering, include **product-quantifying assays** (GC/LC) on target aromatics (e.g., naphthalene, veratryl alcohol).
# - **Expression is tractable in E. coli for rCviUPO** (enabling high-throughput mutagenesis), but secretion/glycosylation-dependent UPOs often require yeast/fungal hosts; stability and folding can be bottlenecks.
# - **Key knowledge gap for aromatics**: fewer structure–activity maps exist versus fatty-acid oxygenation; opportunities lie in **mapping aromatic binding determinants** (π-stacking, channel polarity, gating residues) and **tuning the distal pocket** to favor oxygen transfer over ET.
#
# ---
#
# ## 2. Structural Overview
# ### Fold classification
# - **Heme-thiolate peroxidase/peroxygenase fold**, related to chloroperoxidase-like enzymes (HTP superfamily). UPOs are distinct from classical plant peroxidases and from P450s but share the **thiolate axial ligand** feature with P450s.
#
# ### Domain architecture
# - Typically **single-domain globular enzyme** with a **buried heme** and a **solvent-exposed access channel** leading to the distal face of the heme.
# - Many fungal UPOs are **secreted** and may be **glycosylated** in native hosts; recombinant bacterial versions (e.g., rCviUPO) are used for engineering.
#
# ### Active site organization (conserved motifs/residues)
# - **Axial ligand:** conserved **Cys** (thiolate) coordinating heme iron (P450-like).
# - **Proximal motif:** commonly reported as **–PCP–** around the axial cysteine region in UPO-like sequences; UPObase highlights motif differences between UPOs and CPOs (UPO: **–PCP–EGD–R–E** vs CPO: **–PCP–EHD–E** patterning reported in the database paper).
# - **Distal acid/base:** a **Glu/Asp** in the distal pocket is implicated in **H₂O₂ activation** (heterolytic O–O cleavage to Compound I), analogous in function to the distal acid in peroxidases/CPOs.
#
# ### Access channels / substrate tunnels
# - A **heme access channel** is a dominant determinant of substrate scope and regioselectivity.
# - **Validated engineering handle:** in rCviUPO, multiple **channel residues were alanine-substituted**; **F88A/T158A** (channel-opening) improved oxygenation performance (shown for epoxidation of unsaturated fatty acids; mechanistically consistent with improving substrate approach/orientation at the oxoferryl).
#
# ### Cofactor binding
# - **Heme b** (protoporphyrin IX) is the only cofactor; no flavin or external reductase required.
#
# ---
#
# ## 3. Reaction Mechanism (focused on aromatic peroxygenation)
# ### Catalytic cycle (peroxygenation mode)
# 1. **Resting state:** ferric heme **Fe(III)**–S(Cys).
# 2. **H₂O₂ binding** at distal site → formation of **Compound 0** (Fe(III)–OOH, hydroperoxo).
# 3. **Heterolytic O–O cleavage** (acid/base-assisted) → **Compound I**: **Fe(IV)=O + porphyrin π‑cation radical**.
# 4. **Substrate oxidation (oxygen transfer):**
#    - For aromatic hydroxylation/epoxidation: Compound I performs **oxygen insertion** via H‑abstraction/oxygen rebound or electrophilic addition depending on substrate class.
# 5. **Return to resting state** via **Compound II** (Fe(IV)=O) and subsequent steps.
#
# ### Key intermediates
# - **Compound 0, Compound I, Compound II** are central.
# - For epoxidation, literature on UPOs proposes a transient **Cpd II*–substrate radical complex** facilitating ring closure (explicitly discussed in the rCviUPO epoxidation engineering paper; concept may extend to aromatic epoxidations).
#
# ### Rate-limiting steps (what’s known/likely)
# - Often **H₂O₂ activation vs productive substrate oxidation** competes with **uncoupling**; apparent rate limitation can shift with H₂O₂ dosing and substrate binding affinity/orientation.
#
# ### Competing pathways: peroxygenation vs peroxidation
# - **Peroxidation (1e⁻ oxidation)** yields **substrate radicals** (e.g., ABTS•⁺; phenoxy radicals), promoting **coupling/oligomerization**.
# - For polyphenols (e.g., rutin), experiments show that **radical scavengers (ascorbate)** can **redirect outcomes toward hydroxylated products** by quenching radical pathways (process lever to favor peroxygenation).
#
# ### Determinants of chemo-/regioselectivity
# - **Binding pose in the channel** (sterics, π-interactions, polarity) controls which aromatic carbon approaches the oxoferryl.
# - **Channel openness** (e.g., F88A/T158A in rCviUPO) can increase productive binding for bulky/hydrophobic substrates but may also increase unproductive H₂O₂ access (potentially lowering H₂O₂ tolerance—needs testing).
#
# ---
#
# ## 4. Substrate Scope & Selectivity Trends (with your targets in mind)
# ### Broad accepted classes (UPO generality)
# - **Aromatics:** hydroxylation/epoxidation; also O-/N-dealkylations for substituted aromatics (UPO hallmark).
# - **Aliphatics:** (sub)terminal hydroxylation, epoxidation of alkenes, fatty-acid oxygenation and even chain-shortening cascades (demonstrates strong C–H oxidation competence).
# - **Peroxidase substrates:** dyes/phenolics (ABTS), leading to radical chemistry.
#
# ### Engineering-relevant trends
# - **Hydrophobic aromatics (e.g., naphthalene):** likely limited by **channel hydrophobicity and size**; opening mutations and hydrophobic lining optimization are plausible.
# - **Veratryl alcohol (aromatic alcohol):** can undergo benzylic oxidation/hydroxylation pathways; product distribution can be sensitive to peroxidative side chemistry depending on conditions.
# - **NBD / ABTS:** often act as **reporter substrates**; ABTS strongly reports peroxidative activity and may not correlate with aromatic hydroxylation performance.
#
# ### Known limitations
# - **Overoxidation** (multiple oxygenations) and **radical coupling** for phenolic substrates.
# - **H₂O₂-driven inactivation** limits TTN unless peroxide is carefully metered.
#
# ---
#
# ## 5. Engineering Landscape
# ### Mutations affecting activity/selectivity (validated)
# - **rCviUPO heme-channel alanine substitutions** improved oxygenation of fatty substrates; the key validated pair:
#   - **F88A/T158A**: enhanced epoxidation of linoleic and α-linolenic acids; achieved **>80% desired diepoxides** after near-complete conversion; process optimization enabled **up to 85% epoxidation yield in 1 h** at much higher substrate loading.
#   *Engineering inference for aromatics:* analogous channel-opening can improve aromatic access/orientation, but must be balanced against peroxide access/uncoupling.
#
# ### Stability-enhancing mutations
# - Not well covered in the provided hits; generally pursued via:
#   - **surface charge optimization**, **disulfide engineering**, **rigidifying loops near the channel**, and **glycosylation-aware designs** (host-dependent).
#   *Gap/opportunity:* systematic stability maps for UPOs under cosolvent + H₂O₂ are still sparse.
#
# ### Expression improvements
# - **rCviUPO is produced in E. coli** (enables rapid engineering). Many other UPOs are secreted fungal proteins that can be harder to express functionally in bacteria.
#
# ### Channel reshaping strategies (most actionable)
# - **Alanine scanning / saturation mutagenesis** at channel residues (like F88, T158 and neighboring positions) to tune:
#   - substrate size acceptance,
#   - aromatic binding pose (regioselectivity),
#   - peroxygenation/peroxidation balance (via residence time/orientation).
#
# ### ML-guided/computational design
# - Not represented in the provided citations; a practical route is to combine:
#   - **AlphaFold2 models** (for homolog selection and residue mapping),
#   - **tunnel analysis** (CAVER/MOLE),
#   - **docking + short MD** to prioritize channel mutations,
#   - then **Bayesian optimization/active learning** on small libraries using LC/GC product readouts.
#
# ---
#
# ## 6. Practical Constraints (biocatalysis / green chemistry context)
# - **H₂O₂ sensitivity:** primary operational constraint; requires controlled dosing (syringe pump) or in situ generation (e.g., oxidase systems) to avoid rapid inactivation.
# - **Uncoupling/inactivation pathways:** excess peroxide → oxidative damage to heme/protein; radical pathways can also damage enzyme.
# - **Solvent tolerance:** often needed for hydrophobic aromatics (naphthalene). Expect trade-offs: cosolvent improves solubility but can destabilize UPO; screen %MeCN/%EtOH/%DMSO with peroxide feed.
# - **Reusability/immobilization:** membrane reactor work on AaeUPO+rutin highlighted **activity loss during filtration/reuse**, indicating formulation/immobilization needs careful optimization (shear, interfaces, peroxide gradients).
#
# ---
#
# ## 7. Comparative Analysis (seed: CviUPO; general UPO context)
# - **CviUPO (recombinant, E. coli-expressible)** is an engineering-friendly scaffold with demonstrated channel mutability and high oxygenation performance on hydrophobic chains.
# - **AaeUPO** is a canonical, widely studied UPO for aromatic transformations but can show strong peroxidative side reactions with polyphenols; process additives (ascorbate) can shift selectivity.
# - **Implication:** if your priority is **rapid library iteration + expression**, CviUPO is attractive; if your priority is **aromatic peroxygenation precedent**, AaeUPO literature is richer but may be harder to engineer at scale depending on expression system.
#
# ---
#
# ## 8. Engineering Opportunities (actionable hypotheses for aromatic peroxygenation)
# ### A. Mutation target zones (CviUPO-centric, transferable logic)
# 1. **Heme access channel “bottleneck” residues**
#    - Start from **F88 and T158** (validated). Build **small focused libraries**:
#      - F88: A/V/L/I (tune size/hydrophobics)
#      - T158: A/S/V (tune polarity/space)
#    - Add 2–4 neighboring channel residues (from structure/model) for combinatorial libraries (≤200–500 variants).
#
# 2. **Distal pocket polarity tuning**
#    - For aromatics, introduce **π-friendly/hydrophobic residues** to stabilize binding pose (but avoid increasing peroxidase ET on phenolics).
#    - If peroxidation dominates (ABTS high, hydroxylation low), consider **reducing ET propensity** by altering residues that stabilize radical intermediates (requires structure-guided selection).
#
# ### B. Process levers to bias peroxygenation over peroxidation
# - **Peroxide feed control** (low steady-state H₂O₂).
# - **Radical scavengers** (ascorbate demonstrated to redirect rutin chemistry toward hydroxylated products; test for your aromatic panels, but monitor whether scavenger competes with desired oxidation).
# - **Two-tier screening:** (i) activity screen (ABTS) for expression/folding, then (ii) **product screen** on naphthalene/veratryl alcohol by GC/LC.
#
# ### C. Assay design suggestions (for your substrates)
# - **Naphthalene:** GC-MS quantification of naphthol isomers; use biphasic or cosolvent system; include internal standard; run peroxide-fed reactions.
# - **Veratryl alcohol:** LC/GC for veratraldehyde/veratric acid/hydroxylated products; track overoxidation.
# - **NBD/ABTS:** use only as **folding/activity reporters**, not as primary objective metrics for aromatic peroxygenation.
#
# ### D. Knowledge gaps to exploit
# - Build a **structure–selectivity map for aromatics** (regioisomer ratios vs channel mutations) analogous to what exists for fatty-acid oxygenation. This is a high-value dataset for **ML-guided optimization**.
#
# ---
#
# ## 9. References (provided hits + key context from them)
# - **Linde, D.; González-Benjumea, A.; Aranda, C.; Carro, J.; Gutiérrez, A.; Martínez, A. T.** (2022). *Engineering Collariella virescens Peroxygenase for Epoxides Production from Vegetable Oil.* **Antioxidants**. DOI: **10.3390/antiox11050915**. (Primary; channel engineering; F88A/T158A; process optimization; mechanistic epoxidation cycle figure/discussion.)
# - **Olmedo, A.; Ullrich, R.; Hofrichter, M.; del Río, J. C.; Martínez, Á. T.; Gutiérrez, A.** (2022). *Novel Fatty Acid Chain-Shortening by Fungal Peroxygenases Yielding 2C-Shorter Dicarboxylic Acids.* **Antioxidants**. DOI: **10.3390/antiox11040744**. PMCID: **PMC9025384**. (Primary; demonstrates breadth of UPO oxidative chemistry and mechanistic versatility.)
# - **Muniba, F.; Dongming, L.; Huang, S.; Wang, Y.** (2019). *UPObase: an online database of unspecific peroxygenases.* **Database (Oxford)**. DOI: **10.1093/database/baz122**. PMCID: **PMC6902001**. (Resource; classification; conserved motifs; notes available crystal structures at the time.)
# - **[Authors not provided in input]** (2024). *Exploiting UPO versatility to transform rutin in more soluble and bioactive products.* **New Biotechnology**. PubMed: **39181196**. (Primary; process variables; peroxygenation vs peroxidation/oligomerization; ascorbate shifts product profile; stability issues in reuse.)
#
# If you can provide **CviUPO sequence/UniProt ID** (or the exact construct used in your lab), I can (i) place it into UPObase subfamily context, (ii) map **channel residues** around F88/T158 in your numbering, and (iii) propose a **minimal first-round library** specifically for **naphthalene/veratryl alcohol** peroxygenation with predicted effects on tunnel radius and binding pose.
# PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/literature_review_llm_summary.md')

# %% [markdown]
# ## Save Thread Update
# Run this final cell to append run metadata and compact LLM summary to `chats/<llm_process_tag>_<thread_id>.json`.

# %%
persist_thread_update(
    root_key=root_key,
    thread_id=thread_id,
    inputs=user_inputs,
    out_paths=out_paths,
    llm_review_path=out_llm,
    llm_review_text=llm_review,
)
# Out:
# '2026-02-11T06:32:28.576987+00:00'
