# %% [markdown]
# # 02 - Binding Pocket Analysis
#
# Notebook UI for UPO homolog pocket analysis using an LLM with binding, alignment, and optional reaction inputs.

# %% [markdown]
# ## Python Path Setup
# Ensure project-root imports work whether Jupyter starts from repo root or `notebooks/`.

# %%
from pathlib import Path
import os
import sys

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %% [markdown]
# ## Imports
# Load helper functions for table loading, LLM analysis, output export, and thread persistence.

# %%
import importlib
import notebook_helpers.nb_02_binding_pocket_analysis as bp
bp = importlib.reload(bp)
from local_api_keys import OPENAI_API_KEY

analyze_pocket_profiles = bp.analyze_pocket_profiles
default_user_inputs = bp.default_user_inputs
build_prompt_with_context = bp.build_prompt_with_context
generate_llm_pocket_analysis = bp.generate_llm_pocket_analysis
init_thread = bp.init_thread
load_input_tables = bp.load_input_tables
persist_thread_update = bp.persist_thread_update
save_binding_outputs = bp.save_binding_outputs
save_llm_analysis = bp.save_llm_analysis
setup_data_root = bp.setup_data_root

# %% [markdown]
# ## API Key Setup
# Load the OpenAI key from `local_api_keys.py` into environment variables for LLM calls.

# %%
if OPENAI_API_KEY and OPENAI_API_KEY != "REPLACE_WITH_YOUR_OPENAI_API_KEY":
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

"OPENAI_API_KEY" in os.environ
# Out:
# True

# %% [markdown]
# ## User Inputs
# Edit all run parameters here (single place): dataset root, thread selection, analysis options, model, and input paths.

# %%
root_key = "PIPS2"
existing_thread_id = "59353c876ab140688b1c239a15aac24e"# None

user_inputs = {
    "selected_positions": None, # [100, 103, 104, 107, 141, 222],
    "focus_question": (
        "Identify per-protein structural interpretations and cross-homolog patterns "
        "that could explain activity/property differences."
    ),
    "reaction_data_description": (
        "- Veratryl alcohol: peroxygenative\n"
        "- Naphthalene: peroxygenative\n"
        "- NBD: peroxygenative\n"
        "- ABTS: peroxidative\n"
        "- S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased\n"
        "Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance."
    ),
    "use_reaction_data": True,
    "llm_model": "gpt-5.2",
    "llm_temperature": 0.2,
    "llm_max_rows_per_table": 300,
}

input_paths = {
    # Paths are relative to the data root from variables.address_dict[root_key].
    "binding_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv",
    "alignment_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv",
    "reaction_data_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv",
}

# Optional: reset analysis options from helper defaults
# user_inputs = default_user_inputs()

# %% [markdown]
# ## Setup Runtime Context
# Initialize data directories and active chat thread from the values above.

# %%
data_root, resolved_dirs = setup_data_root(root_key)
thread, threads_preview = init_thread(root_key, existing_thread_id)
thread_id = thread["thread_id"]
data_root, thread_id
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data'),
#  '59353c876ab140688b1c239a15aac24e')

# %% [markdown]
# ## Load Input Tables
# Load descriptor and alignment tables, and optional reaction data, from `input_paths`.

# %%
def resolve_input_path(path_value: str) -> Path:
    p = Path(path_value).expanduser()
    if p.is_absolute():
        return p.resolve()
    return (data_root / p).resolve()

binding_csv = resolve_input_path(input_paths["binding_csv"])
alignment_csv = resolve_input_path(input_paths["alignment_csv"])
reaction_data_csv = None
if user_inputs.get("use_reaction_data", False) and input_paths.get("reaction_data_csv", "").strip():
    reaction_data_csv = resolve_input_path(input_paths["reaction_data_csv"])

pocket, ali, reaction_df = load_input_tables(binding_csv, alignment_csv, reaction_data_csv)
binding_csv, alignment_csv, reaction_data_csv, pocket.head(3), (None if reaction_df is None else reaction_df.head(3))
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv'),
#     Unnamed: 0                    struct_name                  struct_name.1  \
#  0           0                ET096_S82_glide                ET096_S82_glide
#  1           1               CviUPO_S82_glide               CviUPO_S82_glide
#  2           2  CviUPO-F88L+T158A_S82_chai1_0  CviUPO-F88L+T158A_S82_chai1_0
#
#                     struct_name.2  num_pocket_res_ali  num_pocket_res<6  \
#  0                ET096_S82_glide                  38                12
#  1               CviUPO_S82_glide                  39                13
#  2  CviUPO-F88L+T158A_S82_chai1_0                  33                10
#
#     reactive_center_distance  median_dist_res_to_ligand_reactive_center  \
#  0                     7.095                                      7.921
#  1                     7.720                                      6.683
#  2                     5.827                                      6.922
#
#     median_min_dist_res_to_ligand  mean_min_dist_to_centroid (distal)  ...  \
#  0                          4.330                               8.570  ...
#  1                          3.575                               8.079  ...
#  2                          4.155                               7.691  ...
#
#     kd_weighted (distal)  kd_weighted (proximal)  hw_mean (distal)  \
#  0                 0.967                   2.177            -0.466
#  1                 0.387                   1.055            -0.546
#  2                 0.730                   1.400            -0.658
#
#     hw_mean (proximal)  hw_weighted (distal)  hw_weighted (proximal)  \
#  0              -0.864                -0.464                  -0.940
#  1              -0.946                -0.475                  -0.825
#  2              -0.900                -0.533                  -0.792
#
#     charged_fraction (distal)  charged_fraction (proximal)  \
#  0                      0.132                        0.000
#  1                      0.128                        0.077
#  2                      0.121                        0.077
#
#     polar_fraction (distal)  polar_fraction (proximal)
#  0                    0.368                      0.182
#  1                    0.513                      0.385
#  2                    0.485                      0.308
#
#  [3 rows x 41 columns],
#    UPO Homologs  Veratryl alcohol (peroxygenation)  \
#  0        ET096                              0.597
#  1       CviUPO                              0.333
#  2       DcaUPO                              1.558
#
#     Naphthalene (peroxygenation)  NBD (peroxygenation)  ABTS (peroxidation)  \
#  0                         0.127                 0.053                0.146
#  1                         0.168                 0.169                3.939
#  2                         0.136                 1.242                2.700
#
#     S82 Mono-Ox %yield  S82 Di-Ox % Yield  S82 Total % Yield  S82 Mono:Di Ratio
#  0                 8.4               32.7               41.1                0.3
#  1                14.8                8.9               23.7                1.7
#  2                10.0                6.2               16.2                1.6  )

# %% [markdown]
# ## Structured Exports
# Generate heuristic comparative tables and export CSVs to `processed/`.

# %%
selected_positions = user_inputs["selected_positions"]
interp_df, pattern_summary = analyze_pocket_profiles(pocket, ali, selected_positions)
out_interp, out_patterns = save_binding_outputs(interp_df, pattern_summary, resolved_dirs["processed"])
out_interp, out_patterns
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_interpretations.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_pattern_summary.csv'))

# %% [markdown]
# ## LLM Pocket Analysis
# Query the LLM client with the full prompt and input tables, then save markdown output.
#
# Prerequisite: set `OPENAI_API_KEY` in `local_api_keys.py`.

# %%
prompt_text = build_prompt_with_context(reaction_df, user_inputs)
print("=== Prompt Sent To LLM ===")
print(prompt_text)
print("\n=== LLM Output ===")
llm_analysis = generate_llm_pocket_analysis(pocket, ali, reaction_df, user_inputs)
print(llm_analysis)
out_llm = save_llm_analysis(llm_analysis, resolved_dirs["processed"])
out_llm
# Out:
# === Prompt Sent To LLM ===
#
# Analyse the uploaded inputs for a set of proteins to interpret how binding-pocket structure relates to catalytic activity and selectivity.
# Consider how both the proximal (<6 from docked ligand) and distal (up to 11 angstrom from binding pocket centroid) residues affect the binding pocket environment.
#
# INPUTS
# - binding_pocket_table: table of extracted binding-pocket properties (per protein). Properties are calculated over both "distal" and "proximal" ligands, which represent the residues in the broader pocket region, and closer to the reaction coordinate, respectively.
# - pocket_alignment_table: filtered residue alignment of pocket-proximal positions
# - reaction_data (optional): table or dict summarising enzyme activity on different substrates
#
# TASKS
# 1. For each protein, generate an punchy tagline, as well as a concise **4-5 bullet summary** of its overall binding-pocket geometry and chemistry, addressing the interplay of i) proximal electrostatics, ii) proximal sterics, iii) distal electrostatics, iv) distal sterics and outer pocket size.
# 2. Interpret how these properties are likely to influence **catalytic activity and selectivity**, especially productive (e.g. peroxygenative) vs non-productive or competing (e.g. peroxidative) pathways.
# 3. If variants of the same protein are present, **explicitly contrast them** and explain how observed pocket differences could rationalise functional changes.
# 4. Briefly distil **cross-protein trends or clusters** (“pocket phenotypes”) that explain systematic behaviour differences across the panel.
# 5. Optionally integrate reaction_data to connect structural features to observed substrate-specific behaviour.
# 6. Examine the alignment context, together with the inferred binding pocket descriptions for each protein. Suggest mechanisms and effects of specific mutations observed.
#
# POCKET FEATURES TO CONSIDER
#
# Pocket size / alignment coverage
# - num_pocket_res_ali: number of aligned positions within a distance cutoff of any docked ligand
# - num_pocket_res_lt6: number of residues close to the ligand in each structure
#
# Ligand-dependent geometry
# - reactive_center_distance: distance between ligand reactive atom and catalytic center
# - median_dist_res_to_ligand_reactive_center: median distance between pocket residue centroids and ligand reactive atom
# - median_min_dist_res_to_ligand: median minimum distance between each pocket residue and any ligand heavy atom
#
# Ligand-independent pocket geometry
# - mean_dist_backbone_to_centroid
# - mean_dist_to_centroid
# - mean_min_dist_to_centroid
#
# Side-chain sterics (aligned pocket residues)
# - mean_volume, weighted_mean_volume, volume_variance
# - small_residue_frac, small_residue_frac_weighted
# - bulky_residue_frac, bulky_residue_frac_weighted
#
# Pocket polarity / electrostatics
# - kd_mean, kd_weighted (hydrophobicity; higher = more hydrophobic)
# - hw_mean, hw_weighted (polarity/exposure; more negative = less polar / less exposed)
# - charged_fraction, polar_fraction
#
# ALIGNMENT CONTEXT
# The residue alignment has been filtered to include only positions that:
# - show sequence variability (≥1 amino-acid type or gap), and
# - are within the distance cutoff to the ligand in at least one structure.
# Use this information to reason about which **variable positions directly shape the binding pocket** versus those that are peripheral.
#
# REACTION CONTEXT (OPTIONAL)
# If reaction_data is provided, use it to support structure–function reasoning.
# - Veratryl alcohol: peroxygenative
# - Naphthalene: peroxygenative
# - NBD: peroxygenative
# - ABTS: peroxidative
# - S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased
# Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance.
#
# OUTPUT STYLE
# - Use clear, human-interpretable language.
# - Emphasise geometric and chemical intuition over raw numbers.
# - Keep summaries compact, comparative, and mechanistically grounded.
# - Label residues using the numbering from that sequence, not the overall alignment index.
#
#
# REACTION_DATA_STATUS: provided. Rows=5, Columns=['UPO Homologs', 'Veratryl alcohol (peroxygenation)', 'Naphthalene (peroxygenation)', 'NBD (peroxygenation)', 'ABTS (peroxidation)', 'S82 Mono-Ox %yield', 'S82 Di-Ox % Yield', 'S82 Total % Yield', 'S82 Mono:Di Ratio']
#
# === LLM Output ===
# ## Per-protein pocket interpretations (proximal <6 Å vs distal up to ~11 Å)
#
# ### ET096_S82_glide — **“Hydrophobic, low-charge ‘mono-oxygenation suppressor’ with a roomy outer vestibule.”**
# - **Proximal electrostatics:** very **nonpolar/uncharged** near the ligand (charged_fraction ~0; polar_fraction low), with **high hydrophobicity** (kd_mean ~2.06). Likely weak H-bond steering of the reactive pose.
# - **Proximal sterics:** **small-residue enriched** close to the ligand (small_residue_frac ~0.64) → fewer hard steric constraints; substrate can “wobble” and sample multiple orientations.
# - **Distal electrostatics:** distal region carries **some charge/polarity** (charged_fraction ~0.13; polar_fraction ~0.37) but not strongly polar overall; could support ingress/egress without tightly pre-organizing the reactive pose.
# - **Distal sterics / outer size:** distal residues are on average **bulkier than proximal** (mean_volume distal > proximal) and the distal centroid distances are relatively large → a **broad vestibule** feeding into a **hydrophobic, permissive inner pocket**.
# - **Reaction-coordinate geometry:** **reactive_center_distance ~7.1 Å** (largest in panel) suggests the docked “reactive atom” sits **farther from the catalytic center**, consistent with less productive alignment.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - ET096 shows **low S82 Mono:Di (0.3)** with **high Di-Ox yield** (32.7%). A **nonpolar, low-constraint proximal pocket** plus **longer reactive distance** is consistent with **more non-productive binding modes** and/or easier re-binding for a second oxidation event (driving Di-Ox).
# - Moderate ABTS (0.146) suggests it’s **not strongly peroxidative**, but the pocket features look more like **weak pose control** than strong peroxygenation pre-organization.
#
# **Alignment-linked mechanisms (variable pocket positions):**
# - ET096 has **V74** where others often have L/T; and **A77/A80** where others include polar/charged/bulky residues. This pattern fits a **“de-featured” hydrophobic wall** near the pocket that reduces directional interactions.
# - ET096 also has **F223** (others often smaller/aliphatic) which may **shape the distal gate/vestibule**, potentially favoring substrate residence and repeat oxidation (Di-Ox).
#
# ---
#
# ### CviUPO_S82_glide — **“Polar, bulky, and peroxidation-prone: a ‘sticky’ pocket that over-stabilizes binding.”**
# - **Proximal electrostatics:** **more polar and slightly charged** near the ligand (polar_fraction ~0.39; charged_fraction ~0.08) with **lower hydrophobicity** than ET096 (kd_mean ~1.36). More opportunity for H-bonding/ionic steering.
# - **Proximal sterics:** **very bulky proximal shell** (bulky_residue_frac ~0.62; mean_volume proximal ~111) → tighter shape complementarity, stronger pose restriction.
# - **Distal electrostatics:** **most polar distal environment** in the panel (polar_fraction ~0.51) with some charge → could stabilize multiple binding modes and/or facilitate electron-transfer competent orientations for peroxidative chemistry.
# - **Distal sterics / outer size:** distal centroid distances are not extreme; combined with polarity this suggests a **well-solvated, interactive vestibule** rather than a purely hydrophobic funnel.
# - **Reaction-coordinate geometry:** reactive_center_distance ~7.7 Å (also long), but **median_min_dist_res_to_ligand is smallest** (~3.58 Å) → ligand is **tightly contacted** yet not necessarily positioned productively to the catalytic center.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - CviUPO has **very high ABTS (3.939)** (peroxidation) and **S82 Mono:Di 1.7** (mono favored). A **polar/charged, bulky proximal pocket** can:
#   - **lock** S82 in a single dominant orientation (reducing Di-Ox),
#   - while the **polar/charged environment** may also support **peroxidative pathways** (e.g., better stabilization of charged intermediates or surface-accessible ET-like binding modes).
# - Peroxygenation on small aromatics is moderate (NBD 0.169; naphthalene 0.168), but the standout is **peroxidation bias**.
#
# **Alignment-linked mechanisms / variants context:**
# - Key variable positions include **F88** and **T158** (see variant below). Wild-type CviUPO has **F88** (bulky aromatic) and **T158** (polar), a combination that plausibly **increases proximal crowding + polarity**, matching the “sticky/bulky/polar” phenotype.
#
# ---
#
# ### CviUPO-F88L+T158A_S82_chai1_0 — **“De-aromatized and de-polarized Cvi pocket: closer reactive approach, less ‘peroxidase-like’ grip.”**
# - **Proximal electrostatics:** still somewhat polar/charged (charged_fraction ~0.08) but **less polar than CviUPO** (polar_fraction drops from ~0.39 → ~0.31) and slightly more hydrophobic (kd_mean ~1.63).
# - **Proximal sterics:** remains **bulky-rich** (bulky_residue_frac ~0.62), but the **F→L** swap removes an aromatic face that can enforce π-stacking and rigidify binding.
# - **Distal electrostatics:** distal polarity remains high-ish (polar_fraction ~0.49) but slightly reduced vs CviUPO.
# - **Distal sterics / outer size:** fewer aligned pocket residues (num_pocket_res_ali 33) suggests either **less conserved pocket coverage** or a **more compact/less sampled** pocket region in this structure set.
# - **Reaction-coordinate geometry:** **reactive_center_distance improves to ~5.83 Å** (notably shorter than CviUPO’s ~7.7 Å), consistent with **more productive approach** to the catalytic center.
#
# **Functional expectation (no direct reaction_data row for the variant):**
# - **F88L + T158A** should generally **reduce polar anchoring and aromatic clamping**, allowing the ligand to **sit closer to the catalytic center** (as observed) and potentially **increase peroxygenative efficiency** (better reactive alignment).
# - It may also **reduce ABTS/peroxidative propensity** by removing a polar/aromatic “landing pad” that can stabilize peroxidation-competent binding modes.
#
# **Mutation mechanisms from alignment:**
# - At the aligned position corresponding to **CviUPO 88**, the table shows **CviUPO: F88** vs **variant: L88** with the variant residue sitting **much closer to the reactive center** in this docked pose (distance-to-reactive-center drops strongly). Mechanistically: removing the phenyl ring can **open a channel** or **remove a steric wedge** that previously held the substrate farther out.
# - **T158A** removes an -OH that can H-bond to ligand/solvent, likely **drying** the proximal pocket and shifting toward **peroxygenation-favoring hydrophobic packing**.
#
# ---
#
# ### DcaUPO_S82_glide — **“Tight, hydrophobic inner pocket with a charged outer ring: high peroxygenation capacity, but still peroxidation-competent.”**
# - **Proximal electrostatics:** **strongly nonpolar** near the ligand (polar_fraction ~0.15; charged_fraction ~0.08) with **high hydrophobicity** (kd_mean ~1.87) and very negative hw_mean (less exposed).
# - **Proximal sterics:** **highly bulky proximal shell** (bulky_residue_frac ~0.62) plus **high volume variance** → a **shaped, anisotropic pocket** that can enforce regio-/stereoselective poses.
# - **Distal electrostatics:** **highest distal charged_fraction** in the panel (~0.20) with moderate polarity → an **electrostatically “featured” vestibule** that can steer entry and possibly stabilize alternative binding modes.
# - **Distal sterics / outer size:** distal centroid distances are moderate; not the roomiest vestibule, but not cramped.
# - **Reaction-coordinate geometry:** **reactive_center_distance ~4.93 Å** (short) suggests **good reactive alignment**.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - DcaUPO is **high on peroxygenation markers** (veratryl alcohol 1.558; NBD 1.242) while also showing **substantial ABTS (2.7)**.
# - Mechanistically: the **hydrophobic, well-shaped proximal pocket + short reactive distance** supports **productive peroxygenation** (good approach geometry, reduced water competition).
# - The **charged distal ring** may simultaneously allow **peroxidative activity** by enabling binding/ET-like interactions for polar substrates (ABTS) or by stabilizing charged transition states away from the heme center.
#
# **Alignment-linked mechanisms:**
# - DcaUPO has distinctive residues at several variable positions (e.g., **D58** where others often have T/A; **F154/F** and **G155/G** region differences) that can introduce **distal charge** and **local flexibility**. A distal Asp (D58) is a plausible contributor to the **higher distal charged_fraction** and could modulate substrate guidance or peroxide/water networks.
#
# ---
#
# ### TE314_S82_chai1_0 — **“Hydrophobic funnel with low proximal charge: permissive binding that drifts toward over-oxidation.”**
# - **Proximal electrostatics:** uncharged (charged_fraction ~0) and moderately hydrophobic (kd_mean ~1.81), with moderate polarity (polar_fraction ~0.31).
# - **Proximal sterics:** **less bulky proximally** than the “bulky clamp” enzymes (bulky_residue_frac ~0.31) and relatively low volume variance → fewer strong steric locks.
# - **Distal electrostatics:** distal is quite hydrophobic (kd_mean ~1.44) and not very charged (0.11) → a **hydrophobic approach corridor**.
# - **Distal sterics / outer size:** centroid distances are moderate; overall looks like a **hydrophobic funnel** rather than a highly featured vestibule.
# - **Reaction-coordinate geometry:** **reactive_center_distance ~4.08 Å** (shortest) indicates the docked pose can be very reactive—yet pose control may be weak.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - TE314 shows **S82 Mono:Di 0.7** with **high total yield (36.5)** and substantial Di-Ox (21.5). This fits a model where the enzyme can achieve **reactive approach** (short distance) but lacks the **steric/electrostatic “stop features”** that prevent re-orientation or second oxidation.
# - Without ABTS/peroxygenation panel data here, the pocket suggests **peroxygenation-competent** geometry but **selectivity control** may be the limiting factor.
#
# **Alignment-linked mechanisms:**
# - TE314 has **P84** at a variable position where others often have L/F. Proline can kink/backbone-rigidify a loop, potentially **reshaping the pocket mouth** and affecting how long S82 remains bound (impacting Di-Ox).
#
# ---
#
# ### OA167_S82_swissdock_0 — **“Bulky, dry proximal pocket with a hydrophobic vestibule: high turnover but weak ‘single-shot’ control.”**
# - **Proximal electrostatics:** uncharged (0) and **very buried/low exposure** (hw_mean ~ -1.29; most negative), with moderate hydrophobicity (kd_mean ~1.6).
# - **Proximal sterics:** **bulky proximal enrichment** (bulky_residue_frac ~0.54; weighted_mean_volume proximal ~111) → strong packing once bound.
# - **Distal electrostatics:** distal moderately hydrophobic (kd_mean ~1.07) with modest polarity/charge.
# - **Distal sterics / outer size:** centroid distances similar to others; not exceptionally large, but the combination of **hydrophobic vestibule + dry proximal site** suggests good capture of hydrophobic substrates.
# - **Reaction-coordinate geometry:** reactive_center_distance ~4.55 Å (good).
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - OA167 has **highest S82 total yield (46.8)** but **Mono:Di 0.6** with high Di-Ox (29.3). This is consistent with:
#   - efficient binding/turnover in a **dry, packing-friendly** pocket (high total),
#   - but insufficient geometric/electrostatic gating to prevent **repeat oxidation** (Di-Ox remains high).
#
# **Alignment-linked mechanisms:**
# - OA167 shows **T73** where many have L/V (more polar at the rim), and **F177** where others often have G (notably at the “Gly gate” position). **F177 vs G** is a strong candidate for altering **local constriction and aromatic contacts**, potentially increasing residence time and promoting Di-Ox.
#
# ---
#
# ## Explicit contrasts among variants/homologs
#
# ### CviUPO vs CviUPO-F88L+T158A (designed variant)
# - **Reactive alignment:** variant shows a **much shorter reactive_center_distance** (~5.8 Å vs ~7.7 Å) → more peroxygenation-ready geometry.
# - **Chemistry:** variant is **less polar proximally** (T158A effect) and less aromatic clamping (F88L), likely **reducing peroxidation-favoring “sticky polar” interactions**.
# - **Net expectation:** shift from **peroxidation-prone, tightly contacted but mispositioned** binding (WT) toward **more productively positioned** binding (variant), potentially improving peroxygenation and/or changing regioselectivity.
#
# ### ET096 vs (TE314/OA167)
# - ET096 has **much more “small-residue” proximal character** and the **worst reactive distance**, matching its **strong Di-Ox bias** (Mono:Di 0.3).
# - TE314/OA167 achieve **short reactive distances** (reactive poses are accessible), but still show **Di-Ox bias**, implying that **reactive approach alone isn’t sufficient**—you also need **pose-locking features** to enforce single oxidation.
#
# ### DcaUPO vs CviUPO (both ABTS-active, but different pocket logic)
# - DcaUPO combines **productive peroxygenation geometry** (short distance, hydrophobic proximal) with **charged distal steering**, giving **high peroxygenation + still high ABTS**.
# - CviUPO is **polar/bulky proximally** and shows **extreme ABTS**, suggesting its pocket environment is more generally supportive of **peroxidative binding modes** (and/or less “dry” near the reactive center).
#
# ---
#
# ## Cross-protein “pocket phenotypes” (clusters)
#
# 1. **“Dry hydrophobic reactor” phenotype (peroxygenation-favoring core)**
#    - Features: **low proximal charge/polarity**, **high proximal hydrophobicity**, **short reactive_center_distance**.
#    - Best exemplar here: **DcaUPO** (also TE314/OA167 geometrically, though selectivity differs).
#    - Expected behavior: strong peroxygenation potential; selectivity depends on steric locking.
#
# 2. **“Sticky polar clamp” phenotype (peroxidation-prone / ABTS-high)**
#    - Features: **higher proximal polarity/charge**, **bulky proximal residues**, tight ligand contacts but not necessarily short reactive distance.
#    - Exemplar: **CviUPO**.
#    - Expected behavior: elevated peroxidation (ABTS), mono-oxidation favored if pose is locked.
#
# 3. **“Permissive hydrophobic cavity” phenotype (over-oxidation / Di-Ox bias)**
#    - Features: **low proximal charge**, **weaker steric constraints** (more small residues or lower bulky fraction), and/or **large vestibule** enabling multiple poses and re-binding.
#    - Exemplar: **ET096** (extreme), also **TE314/OA167** in outcome (Di-Ox) but via slightly different mechanics (they are reactive but not gated).
#
# ---
#
# ## Mutation/position-level hypotheses from the pocket alignment (variable positions that likely matter)
#
# Below are variable positions that appear close enough (in at least one structure) to plausibly shape pocket behavior; mechanisms are inferred from residue type changes + proximity metrics in the alignment table:
#
# - **Position ~CviUPO 88 / TE314 108 / OA167 104 / ET096 103 (hydrophobic wall near pocket):**
#   - **CviUPO F88 → variant L88**: removes aromatic stacking and can **open space** or reduce rigid binding; consistent with **improved reactive distance** in the variant.
# - **Position ~CviUPO 158 / TE314 183 / OA167 174 / ET096 171 (mid-pocket shaping):**
#   - **T158A** removes H-bonding and slightly reduces side-chain volume → tends to **dry the pocket** and reduce polar anchoring, often beneficial for **peroxygenation**.
# - **“Gly gate” region ~CviUPO 161 / DcaUPO 157 / TE314 186 / OA167 177 / ET096 174:**
#   - Many enzymes have **Gly**, but **OA167 has F177** and **ET096 has L174**. Replacing Gly with bulky residues can **constrict/reshape** the channel and increase hydrophobic contacts, potentially increasing **substrate residence time** and promoting **Di-Ox**.
# - **Early pocket rim positions (~55–64 region):**
#   - **DcaUPO D58** (others often T/A) introduces a **distal negative charge** that could steer substrate entry or stabilize polar substrates—consistent with DcaUPO’s **higher distal charged_fraction** and ABTS competence.
#
# ---
#
# ### One-line synthesis linking structure → function across the panel
# Peroxygenation competence tracks best with a **short reactive approach in a dry, hydrophobic proximal pocket**, while the **balance between mono- vs di-oxidation** is dominated by how strongly the pocket **locks a single productive pose** (bulky/featured clamp) versus allowing **pose drift and re-binding** (permissive cavity/large vestibule); **peroxidation (ABTS)** rises with **proximal/distal polarity and charge** that can stabilize non-peroxygenative binding modes.
#
# If you want, I can also (i) rank the proteins by “peroxygenation-likeness” vs “peroxidation-likeness” using a simple composite score from the provided features, and (ii) propose 3–5 concrete mutation ideas per scaffold targeting Mono:Di control (tightening/loosening specific gates highlighted by the alignment).
# PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_llm_analysis.md')

# %% [markdown]
# ## Save Thread Update
# Run this final cell to append run metadata and prompt context to `chats/<thread_id>.json`.

# %%
persist_thread_update(
    root_key=root_key,
    thread_id=thread_id,
    user_inputs=user_inputs,
    input_paths=input_paths,
    selected_positions=selected_positions,
    reaction_df=reaction_df,
    out_interp=out_interp,
    out_patterns=out_patterns,
    llm_analysis_path=out_llm,
    llm_analysis_text=llm_analysis,
    llm_model=str(user_inputs.get("llm_model", "")),
)
# Out:
# '2026-02-11T11:40:30.647192+00:00'
