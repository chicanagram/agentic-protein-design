# %% [markdown]
# # 02 - Binding Pocket Analysis
#
# Notebook UI for UPO homolog pocket analysis using an LLM with binding, alignment, and optional reaction inputs.

# %% [markdown]
# ## Python Path Setup
# Ensure project-root imports work whether Jupyter starts from repo root or `notebooks/`.

# %%
from pathlib import Path
import os
import sys

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %% [markdown]
# ## Imports
# Load helper functions for table loading, LLM analysis, output export, and thread persistence.

# %%
import importlib
import notebook_helpers.nb_02_binding_pocket_analysis as bp
bp = importlib.reload(bp)
from local_api_keys import OPENAI_API_KEY

analyze_pocket_profiles = bp.analyze_pocket_profiles
default_user_inputs = bp.default_user_inputs
build_prompt_with_context = bp.build_prompt_with_context
generate_llm_pocket_analysis = bp.generate_llm_pocket_analysis
init_thread = bp.init_thread
load_input_tables = bp.load_input_tables
persist_thread_update = bp.persist_thread_update
save_binding_outputs = bp.save_binding_outputs
save_llm_analysis = bp.save_llm_analysis
setup_data_root = bp.setup_data_root

# %% [markdown]
# ## API Key Setup
# Load the OpenAI key from `local_api_keys.py` into environment variables for LLM calls.

# %%
if OPENAI_API_KEY and OPENAI_API_KEY != "REPLACE_WITH_YOUR_OPENAI_API_KEY":
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

"OPENAI_API_KEY" in os.environ
# Out:
# True

# %% [markdown]
# ## User Inputs
# Edit all run parameters here (single place): dataset root, thread selection, analysis options, model, and input paths.

# %%
root_key = "PIPS2"
existing_thread_id = "59353c876ab140688b1c239a15aac24e"# None

user_inputs = {
    "selected_positions": None, # [100, 103, 104, 107, 141, 222],
    "focus_question": (
        "Identify per-protein structural interpretations and cross-homolog patterns "
        "that could explain activity/property differences."
    ),
    "reaction_data_description": (
        "- Veratryl alcohol: peroxygenative\n"
        "- Naphthalene: peroxygenative\n"
        "- NBD: peroxygenative\n"
        "- ABTS: peroxidative\n"
        "- S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased\n"
        "Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance."
    ),
    "use_reaction_data": True,
    "llm_model": "gpt-5.2",
    "llm_temperature": 0.2,
    "llm_max_rows_per_table": 300,
}

input_paths = {
    # Paths are relative to the data root from variables.address_dict[root_key].
    "binding_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv",
    "alignment_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv",
    "reaction_data_csv": "pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv",
}

# Optional: reset analysis options from helper defaults
# user_inputs = default_user_inputs()

# %% [markdown]
# ## Setup Runtime Context
# Initialize data directories and active chat thread from the values above.

# %%
data_root, resolved_dirs = setup_data_root(root_key)
thread, threads_preview = init_thread(root_key, existing_thread_id)
thread_id = thread["thread_id"]
data_root, thread_id
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data'),
#  '59353c876ab140688b1c239a15aac24e')

# %% [markdown]
# ## Load Input Tables
# Load descriptor and alignment tables, and optional reaction data, from `input_paths`.

# %%
def resolve_input_path(path_value: str) -> Path:
    p = Path(path_value).expanduser()
    if p.is_absolute():
        return p.resolve()
    return (data_root / p).resolve()

binding_csv = resolve_input_path(input_paths["binding_csv"])
alignment_csv = resolve_input_path(input_paths["alignment_csv"])
reaction_data_csv = None
if user_inputs.get("use_reaction_data", False) and input_paths.get("reaction_data_csv", "").strip():
    reaction_data_csv = resolve_input_path(input_paths["reaction_data_csv"])

pocket, ali, reaction_df = load_input_tables(binding_csv, alignment_csv, reaction_data_csv)
binding_csv, alignment_csv, reaction_data_csv, pocket.head(3), (None if reaction_df is None else reaction_df.head(3))
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/bindingpocket_analysis.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/msa/reps_ali_withDist_FILT.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/pdb/UPOs_peroxygenation_analysis/docked/REPS/substrate_reaction_data.csv'),
#     Unnamed: 0                    struct_name                  struct_name.1  \
#  0           0                ET096_S82_glide                ET096_S82_glide
#  1           1               CviUPO_S82_glide               CviUPO_S82_glide
#  2           2  CviUPO-F88L+T158A_S82_chai1_0  CviUPO-F88L+T158A_S82_chai1_0
#
#                     struct_name.2  num_pocket_res_ali  num_pocket_res<6  \
#  0                ET096_S82_glide                  38                12
#  1               CviUPO_S82_glide                  39                13
#  2  CviUPO-F88L+T158A_S82_chai1_0                  33                10
#
#     reactive_center_distance  median_dist_res_to_ligand_reactive_center  \
#  0                     7.095                                      7.921
#  1                     7.720                                      6.683
#  2                     5.827                                      6.922
#
#     median_min_dist_res_to_ligand  mean_min_dist_to_centroid (distal)  ...  \
#  0                          4.330                               8.570  ...
#  1                          3.575                               8.079  ...
#  2                          4.155                               7.691  ...
#
#     kd_weighted (distal)  kd_weighted (proximal)  hw_mean (distal)  \
#  0                 0.967                   2.177            -0.466
#  1                 0.387                   1.055            -0.546
#  2                 0.730                   1.400            -0.658
#
#     hw_mean (proximal)  hw_weighted (distal)  hw_weighted (proximal)  \
#  0              -0.864                -0.464                  -0.940
#  1              -0.946                -0.475                  -0.825
#  2              -0.900                -0.533                  -0.792
#
#     charged_fraction (distal)  charged_fraction (proximal)  \
#  0                      0.132                        0.000
#  1                      0.128                        0.077
#  2                      0.121                        0.077
#
#     polar_fraction (distal)  polar_fraction (proximal)
#  0                    0.368                      0.182
#  1                    0.513                      0.385
#  2                    0.485                      0.308
#
#  [3 rows x 41 columns],
#    UPO Homologs  Veratryl alcohol (peroxygenation)  \
#  0        ET096                              0.597
#  1       CviUPO                              0.333
#  2       DcaUPO                              1.558
#
#     Naphthalene (peroxygenation)  NBD (peroxygenation)  ABTS (peroxidation)  \
#  0                         0.127                 0.053                0.146
#  1                         0.168                 0.169                3.939
#  2                         0.136                 1.242                2.700
#
#     S82 Mono-Ox %yield  S82 Di-Ox % Yield  S82 Total % Yield  S82 Mono:Di Ratio
#  0                 8.4               32.7               41.1                0.3
#  1                14.8                8.9               23.7                1.7
#  2                10.0                6.2               16.2                1.6  )

# %% [markdown]
# ## Structured Exports
# Generate heuristic comparative tables and export CSVs to `processed/`.

# %%
selected_positions = user_inputs["selected_positions"]
interp_df, pattern_summary = analyze_pocket_profiles(pocket, ali, selected_positions)
out_interp, out_patterns = save_binding_outputs(interp_df, pattern_summary, resolved_dirs["processed"])
out_interp, out_patterns
# Out:
# (PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_interpretations.csv'),
#  PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_pattern_summary.csv'))

# %% [markdown]
# ## LLM Pocket Analysis
# Query the LLM client with the full prompt and input tables, then save markdown output.
#
# Prerequisite: set `OPENAI_API_KEY` in `local_api_keys.py`.

# %%
prompt_text = build_prompt_with_context(reaction_df, user_inputs)
print("=== Prompt Sent To LLM ===")
print(prompt_text)
print("\n=== LLM Output ===")
llm_analysis = generate_llm_pocket_analysis(pocket, ali, reaction_df, user_inputs)
print(llm_analysis)
out_llm = save_llm_analysis(llm_analysis, resolved_dirs["processed"])
out_llm
# Out:
# === Prompt Sent To LLM ===
#
# Analyse the uploaded inputs for a set of proteins to interpret how binding-pocket structure relates to catalytic activity and selectivity.
# Consider how both the proximal (<6 from docked ligand) and distal (up to 11 angstrom from binding pocket centroid) geometries and electrostatics binding pocket environment.
#
# INPUTS
# - binding_pocket_table: table of extracted binding-pocket properties (per protein). Properties are calculated over both "distal" and "proximal" ligands, which represent the residues in the broader pocket region, and closer to the reaction coordinate, respectively.
# - pocket_alignment_table: filtered residue alignment of pocket-proximal positions
# - reaction_data (optional): table or dict summarising enzyme activity on different substrates
#
# TASKS
# 1. For each protein, generate a concise **3–4 bullet summary** of its binding-pocket geometry and chemistry, considering both distal and proximal effects.
# 2. Interpret how these properties are likely to influence **catalytic activity and selectivity**, especially productive (e.g. peroxygenative) vs non-productive or competing (e.g. peroxidative) pathways.
# 3. If variants of the same protein are present, **explicitly contrast them** and explain how observed pocket differences could rationalise functional changes.
# 4. Briefly distil **cross-protein trends or clusters** (“pocket phenotypes”) that explain systematic behaviour differences across the panel.
# 5. Optionally integrate reaction_data to connect structural features to observed substrate-specific behaviour.
#
# POCKET FEATURES TO CONSIDER
#
# Pocket size / alignment coverage
# - num_pocket_res_ali: number of aligned positions within a distance cutoff of any docked ligand
# - num_pocket_res_lt6: number of residues close to the ligand in each structure
#
# Ligand-dependent geometry
# - reactive_center_distance: distance between ligand reactive atom and catalytic center
# - median_dist_res_to_ligand_reactive_center: median distance between pocket residue centroids and ligand reactive atom
# - median_min_dist_res_to_ligand: median minimum distance between each pocket residue and any ligand heavy atom
#
# Ligand-independent pocket geometry
# - mean_dist_backbone_to_centroid
# - mean_dist_to_centroid
# - mean_min_dist_to_centroid
#
# Side-chain sterics (aligned pocket residues)
# - mean_volume, weighted_mean_volume, volume_variance
# - small_residue_frac, small_residue_frac_weighted
# - bulky_residue_frac, bulky_residue_frac_weighted
#
# Pocket polarity / electrostatics
# - kd_mean, kd_weighted (hydrophobicity; higher = more hydrophobic)
# - hw_mean, hw_weighted (polarity/exposure; more negative = less polar / less exposed)
# - charged_fraction, polar_fraction
#
# ALIGNMENT CONTEXT
# The residue alignment has been filtered to include only positions that:
# - show sequence variability (≥1 amino-acid type or gap), and
# - are within the distance cutoff to the ligand in at least one structure.
# Use this information to reason about which **variable positions directly shape the binding pocket** versus those that are peripheral.
#
# REACTION CONTEXT (OPTIONAL)
# If reaction_data is provided, use it to support structure–function reasoning.
# - Veratryl alcohol: peroxygenative
# - Naphthalene: peroxygenative
# - NBD: peroxygenative
# - ABTS: peroxidative
# - S82: mixed; Mono-Ox ~ peroxygenation-biased, Di-Ox ~ peroxidation-biased
# Use ratios (e.g. Mono-Ox : Di-Ox) to infer peroxygenation vs peroxidation balance.
#
# OUTPUT STYLE
# - Use clear, human-interpretable language.
# - Emphasise geometric and chemical intuition over raw numbers.
# - Keep summaries compact, comparative, and mechanistically grounded.
#
#
# REACTION_DATA_STATUS: provided. Rows=5, Columns=['UPO Homologs', 'Veratryl alcohol (peroxygenation)', 'Naphthalene (peroxygenation)', 'NBD (peroxygenation)', 'ABTS (peroxidation)', 'S82 Mono-Ox %yield', 'S82 Di-Ox % Yield', 'S82 Total % Yield', 'S82 Mono:Di Ratio']
#
# === LLM Output ===
# ## 1) Per-protein pocket summaries (geometry + chemistry; proximal vs distal) and functional interpretation
#
# ### **ET096_S82**
# - **Very hydrophobic, decharged proximal microenvironment:** proximal kd_mean ~2.06 with **0 charged residues** and low polar fraction (~0.18). Distal region is much less hydrophobic and includes some charge (charged_fraction ~0.13), implying a **hydrophobic “inner” pocket embedded in a more mixed outer vestibule**.
# - **Proximal pocket is “small-residue rich” and less bulky:** proximal small_residue_frac ~0.64 (highest in panel) with lower bulky fraction (~0.27), consistent with a **more open/forgiving near-heme shape** but with fewer polar/charged steering interactions.
# - **Reactive placement is relatively poor for S82:** reactive_center_distance ~7.10 Å (largest among the set), despite reasonable overall ligand contact counts (num_pocket_res<6 = 12). This suggests **binding occurs but often not in a productive near-oxidant pose**.
# - **Alignment hints at a distinct local architecture near the ligand:** ET096 has gaps at some positions that are present in others (e.g., around alignment indices 104 and 221), consistent with **loop/side-chain differences that can reshape the access channel and pose control**.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - ET096 shows **low Mono:Di (0.3)** with high Di-Ox yield (32.7%). The combination of **(i) very hydrophobic, uncharged proximal environment** and **(ii) long reactive-center distance** is consistent with **weak geometric control of the reactive atom relative to Cpd I**, increasing the probability of **secondary oxidation (Di-Ox) and/or non-productive orientations** once the substrate is bound.
# - ET096 also has **low ABTS (0.146)** relative to CviUPO/DcaUPO, consistent with **less favorable outer-surface/vestibule electrostatics for one-electron peroxidative turnover** (distal pocket has some charge, but the proximal region is notably decharged and “non-polar dominated,” which often correlates with weaker ET-friendly polar networks).
#
# ---
#
# ### **CviUPO_S82**
# - **More polar/charged pocket overall (especially distal):** distal polar_fraction ~0.51 and charged_fraction ~0.13; proximal still retains charge (~0.077) and higher polarity (~0.39) than most others. This supports a **more electrostatically structured access channel**.
# - **Proximal region is sterically “bulky”:** proximal bulky_residue_frac ~0.62 (high) with relatively low small-residue fraction (~0.15), implying a **tighter, shape-selective near-heme pocket**.
# - **Good ligand contact and closer approach than ET096:** median_min_dist_res_to_ligand ~3.58 Å (tight contacts) and num_pocket_res<6 = 13. Reactive_center_distance is still long-ish (7.72 Å), suggesting **tight binding but not necessarily optimal reactive-atom placement for this docked S82 pose**.
# - **Key variable positions near pocket include aromatic/tyrosine features:** e.g., Y at alignment index 224 (CviUPO 160Y) and F at index 141 (CviUPO 88F), consistent with **π-stacking/anchoring that can enforce specific substrate orientations**.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - CviUPO has **very high ABTS (3.939)** and **Mono:Di = 1.7**. The **more polar/charged pocket + bulky proximal shaping** is consistent with:
#   - enhanced **peroxidative competence** (better ET-supporting polar networks and/or access for ABTS-like substrates),
#   - but also **better control against over-oxidation on S82** (higher Mono:Di), plausibly by **restricting substrate repositioning** after the first oxidation.
# - Moderate peroxygenation on small aromatics (naphthalene/NBD) fits a pocket that can bind aromatics via π contacts, but whose **proximal steric constraints** may limit productive poses for some substrates.
#
# ---
#
# ### **CviUPO-F88L+T158A (variant)**
# - **Designed reduction in aromatic/polar anchoring at two positions:** F88L removes an aromatic clamp; T158A removes a polar side chain. Net effect should be **less specific H-bond/π guidance** and slightly more hydrophobic character locally (proximal kd_mean ~1.63).
# - **Geometry suggests improved “reactive placement” vs WT CviUPO:** reactive_center_distance drops to ~5.83 Å (from 7.72 Å), consistent with **easier access of the reactive atom toward the catalytic center** in this docked pose.
# - **Still sterically bulky near the ligand:** proximal bulky_residue_frac remains high (~0.62), so the variant likely **repositions constraints rather than simply enlarging** the pocket.
# - **Slightly reduced alignment coverage / fewer close residues:** num_pocket_res_ali = 33 and num_pocket_res<6 = 10 (both lower than WT), consistent with **a less “encapsulating” pocket** or altered docking engagement.
#
# **Expected functional shift (no reaction_data row provided for this variant):**
# - The **shorter reactive_center_distance** would typically predict **higher peroxygenative efficiency** (more productive HAT/OAT geometry) *if* the pose is stable.
# - However, **loss of polar/π anchoring** can also increase pose heterogeneity, which can **increase side reactions** (including over-oxidation) depending on substrate. Net expectation: **potentially higher activity on substrates needing deeper insertion**, but selectivity could become more substrate-dependent.
#
# ---
#
# ### **DcaUPO_S82**
# - **Best reactive placement among measured homologs:** reactive_center_distance ~4.93 Å (much shorter than ET096/CviUPO), consistent with **more frequent productive near-heme poses** for S82-like substrates.
# - **Strong hydrophobic proximal “inner pocket” with low polarity:** proximal kd_mean ~1.87 and very low polar_fraction (~0.15), while distal has higher charge (charged_fraction ~0.20). This looks like a **hydrophobic catalytic chamber fed by a more electrostatically complex vestibule**.
# - **High proximal steric bulk + high variance:** proximal bulky_residue_frac ~0.62 and very high volume_variance (~1183), suggesting a **rugged, anisotropic pocket** (distinct subcavities / strong shape features) rather than a smooth cavity.
# - **Largest number of close residues:** num_pocket_res<6 = 15, implying **tight packing around the ligand** once bound.
#
# **Likely activity/selectivity consequences (supported by reaction_data):**
# - DcaUPO shows **high peroxygenation on veratryl alcohol (1.558) and NBD (1.242)** while also having **high ABTS (2.7)**. The structural picture supports a generally **highly competent catalyst**: productive placement (short reactive distance) for oxygen transfer, plus enough distal charge/polarity to support peroxidative ET chemistry.
# - **Mono:Di = 1.6** (Mono favored) fits the idea of **tight, bulky proximal shaping** that can lock a preferred mono-oxidation pose and reduce substrate “wandering” that enables second oxidation—despite the proximal region being quite hydrophobic.
#
# ---
#
# ### **TE314_S82**
# - **Very short reactive_center_distance (~4.08 Å):** suggests **high intrinsic geometric readiness** for peroxygenation on S82-like substrates.
# - **More balanced sterics (less bulky proximally):** proximal bulky_residue_frac ~0.31 (low) with moderate small fraction (~0.23), implying a **more permissive near-heme space** than CviUPO/DcaUPO.
# - **Moderately hydrophobic pocket throughout:** distal kd_mean ~1.44 (highest distal hydrophobicity in panel) and proximal kd_mean ~1.81; proximal has **0 charged residues**.
# - **Distal/proximal polarity is moderate:** polar_fraction ~0.37 distal and ~0.31 proximal—more polar than DcaUPO/ET096 proximally, but without charge.
#
# **Likely activity/selectivity consequences (supported by reaction_data for S82 only):**
# - TE314 has **Mono:Di = 0.7** with substantial total yield (36.5). The combination of **excellent reactive placement** but **more permissive proximal sterics** is consistent with **good turnover but weaker control against over-oxidation**, allowing the substrate/product to reorient for a second oxidation event.
# - Lack of proximal charge may reduce peroxidative bias, but without ABTS data here that remains speculative.
#
# ---
#
# ### **OA167_S82**
# - **Good reactive placement (~4.55 Å) with a very “dry” proximal pocket:** proximal hw_mean is most negative (~ -1.29) and **0 charged residues**, consistent with a **highly nonpolar, poorly solvated inner pocket**.
# - **Bulky proximal shaping:** proximal bulky_residue_frac ~0.54 with high weighted_mean_volume (~111), suggesting **strong steric guidance** but also potential for **product trapping** depending on exit channel geometry.
# - **Tighter ligand contacts than many:** median_min_dist_res_to_ligand ~3.60 Å, but fewer close residues (num_pocket_res<6 = 10), implying **localized tight contacts rather than globally tight encapsulation**.
# - **Distinct variable residues near pocket include polar-to-hydrophobic swaps:** e.g., OA167 has T at index 100 (vs mostly L/V) and F at index 225 (vs G in many), which can **reshape channel constrictions and aromatic packing**.
#
# **Likely activity/selectivity consequences (supported by reaction_data for S82 only):**
# - OA167 shows **high total yield (46.8)** but **Mono:Di = 0.6** (Di favored). A plausible mechanism is: **productive first oxidation is easy** (short reactive distance + hydrophobic chamber concentrates substrate), but the **very nonpolar proximal environment** and bulky features may **retain substrate/product near the oxidant**, increasing the chance of **second oxidation** before dissociation.
#
# ---
#
# ## 2) Explicit contrasts among variants / close homologs
#
# ### **CviUPO vs CviUPO-F88L+T158A**
# - **Pose control vs access:** WT CviUPO retains more polar/π anchoring (F88, T158) and shows very high ABTS and high Mono:Di, consistent with **strong orientation control and ET-friendly environment**.
# - The **F88L+T158A** variant shows a **much shorter reactive_center_distance** (more peroxygenation-ready geometry) but slightly reduced pocket engagement (fewer aligned/close residues), consistent with **improved access/deeper insertion** at the cost of **less deterministic positioning**.
# - Net expectation: variant may **increase peroxygenative rate on substrates that need deeper approach**, but selectivity could become **more sensitive to substrate shape** (and potentially more over-oxidation for “sticky” substrates).
#
# ### **ET096 vs (DcaUPO / OA167 / TE314)**
# - ET096 is the outlier with **long reactive distance (~7.1 Å)** and **extremely small-residue-rich proximal pocket**. Despite being hydrophobic, it likely **fails to enforce a productive reactive geometry**, matching its **very low Mono:Di (0.3)** and low ABTS.
#
# ---
#
# ## 3) Cross-protein “pocket phenotypes” (clusters) that explain systematic behavior
#
# ### **Phenotype A: “Productive-geometry, hydrophobic inner chamber” (peroxygenation-competent but over-oxidation-prone)**
# - **Members:** OA167, TE314 (and partly DcaUPO)
# - **Signature:** short reactive_center_distance (~4–4.6 Å) + decharged, hydrophobic proximal region.
# - **Behavioral tendency:** good total turnover on S82, but **Mono:Di < 1** when proximal sterics are permissive or when the pocket is very “dry,” promoting **re-binding/product retention and Di-Ox**.
#
# ### **Phenotype B: “Bulky + polar/charged shaping” (higher control; often higher Mono selectivity; peroxidative competence)**
# - **Members:** CviUPO, DcaUPO
# - **Signature:** high proximal bulky fraction (~0.6) plus **retained polarity/charge** (especially distal; sometimes proximal).
# - **Behavioral tendency:** **higher Mono:Di (>1)** (CviUPO, DcaUPO) consistent with **pose locking**; also **higher ABTS** (both), consistent with **better ET-supporting electrostatics/access**.
#
# ### **Phenotype C: “Hydrophobic but geometrically mis-registered” (non-productive binding / over-oxidation)**
# - **Member:** ET096
# - **Signature:** very hydrophobic, decharged proximal pocket but **long reactive distance** and unusual small-residue enrichment.
# - **Behavioral tendency:** **low Mono:Di** and weaker peroxidative activity, consistent with **binding without productive alignment** and/or **greater pose heterogeneity**.
#
# ---
#
# ## 4) Reaction-data connections (panel-level)
# - **ABTS (peroxidation) tracks with pocket polarity/charge more than with reactive distance:** CviUPO and DcaUPO (higher charged/polar fractions distally and some proximal charge) show **high ABTS**, whereas ET096 (proximal decharged and less polar) shows **very low ABTS**.
# - **S82 Mono:Di appears to reflect “pose control” (bulky shaping + polar anchoring) vs “retention/rewiring” (very hydrophobic, permissive or sticky pockets):**
#   - High Mono:Di: **CviUPO (1.7), DcaUPO (1.6)** → bulky proximal + more structured electrostatics.
#   - Low Mono:Di: **ET096 (0.3), TE314 (0.7), OA167 (0.6)** → either poor reactive alignment (ET096) or strong peroxygenation geometry but weaker control/greater retention (TE314/OA167).
#
# If you want, I can (i) map the specific variable alignment positions to “likely gate/ceiling/floor” roles in the pocket (based on which positions are consistently <~4 Å to ligand across structures), and (ii) propose 2–3 concrete mutation hypotheses per phenotype to shift Mono:Di or ABTS/peroxygenation balance.
# PosixPath('/Users/charmainechia/Documents/projects/PIPS/PIPS2-UPOs-data/processed/binding_pocket_llm_analysis.md')

# %% [markdown]
# ## Save Thread Update
# Run this final cell to append run metadata and prompt context to `chats/<thread_id>.json`.

# %%
persist_thread_update(
    root_key=root_key,
    thread_id=thread_id,
    user_inputs=user_inputs,
    input_paths=input_paths,
    selected_positions=selected_positions,
    reaction_df=reaction_df,
    out_interp=out_interp,
    out_patterns=out_patterns,
    llm_analysis_path=out_llm,
    llm_analysis_text=llm_analysis,
    llm_model=str(user_inputs.get("llm_model", "")),
)
# Out:
# '2026-02-11T09:08:42.160703+00:00'
